# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2023-09-07T16:47:30.502495-07:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.14.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 5.15.0-1029-nvidia
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 256
# Architecture: 64bit

# %%
# %watermark --gpu
# Out:
# GPU Info:
#   GPU 0: NVIDIA A100-SXM4-80GB
#   GPU 1: NVIDIA A100-SXM4-80GB
#   GPU 2: NVIDIA A100-SXM4-80GB
#   GPU 3: NVIDIA A100-SXM4-80GB
#   GPU 4: NVIDIA A100-SXM4-80GB
#   GPU 5: NVIDIA A100-SXM4-80GB
#   GPU 6: NVIDIA A100-SXM4-80GB
#   GPU 7: NVIDIA A100-SXM4-80GB

# %%
from dask.distributed import Client
from dask_cuda import LocalCUDACluster
from dask import dataframe as dd
from dask.delayed import delayed
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

import optuna
import gc
import logging

# %%
# %watermark --iversions
# Out:
# pandas : 1.5.3
# xgboost: 1.7.6
# dask   : 2023.3.2
# logging: 0.5.1.2
# optuna : 3.3.0
# numpy  : 1.24.4

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-80GB (UUID: GPU-cf1d9297-d9c3-6b2a-8afa-e63e4b5abb2d)
# GPU 1: NVIDIA A100-SXM4-80GB (UUID: GPU-6d18acdc-2136-40ac-5eeb-724e81476385)
# GPU 2: NVIDIA A100-SXM4-80GB (UUID: GPU-a87c7d38-52d2-befc-e2de-3cf90f75d6eb)
# GPU 3: NVIDIA A100-SXM4-80GB (UUID: GPU-8e290e7b-dec5-1828-2ec2-a6930ecd4b5b)
# GPU 4: NVIDIA A100-SXM4-80GB (UUID: GPU-36f4174f-2697-e22e-3ae5-0d30e814c4f1)
# GPU 5: NVIDIA A100-SXM4-80GB (UUID: GPU-d0929bb4-8c8c-8418-70d2-f658013f4b33)
# GPU 6: NVIDIA A100-SXM4-80GB (UUID: GPU-78f54132-3566-5a8c-b51b-fb3cc695d648)
# GPU 7: NVIDIA A100-SXM4-80GB (UUID: GPU-61b9f63d-cb20-77e8-8b22-40f40fbb8715)

# %%
cluster = LocalCUDACluster(n_workers=8)
client = Client(cluster)
# Out:
# 2023-09-07 16:47:34,357 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 16:47:34,357 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 16:47:34,358 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 16:47:34,358 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 16:47:34,358 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 16:47:34,358 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 16:47:34,359 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 16:47:34,359 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 16:47:34,359 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 16:47:34,359 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 16:47:34,371 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 16:47:34,371 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 16:47:34,371 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 16:47:34,371 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 16:47:34,371 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 16:47:34,371 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize

# %%
# !nvidia-smi
# Out:
# Thu Sep  7 16:47:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   34C    P0    70W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   32C    P0    67W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-SXM...  On   | 00000000:47:00.0 Off |                    0 |
# | N/A   32C    P0    65W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-SXM...  On   | 00000000:4E:00.0 Off |                    0 |
# | N/A   33C    P0    67W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100-SXM...  On   | 00000000:87:00.0 Off |                    0 |
# | N/A   39C    P0    66W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100-SXM...  On   | 00000000:90:00.0 Off |                    0 |
# | N/A   37C    P0    70W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100-SXM...  On   | 00000000:B7:00.0 Off |                    0 |
# | N/A   36C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100-SXM...  On   | 00000000:BD:00.0 Off |                    0 |
# | N/A   37C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A   3649807      C   /usr/bin/python3                  414MiB |
# |    1   N/A  N/A   3649809      C   /usr/bin/python3                  414MiB |
# |    2   N/A  N/A   3649814      C   /usr/bin/python3                  414MiB |
# |    3   N/A  N/A   3649815      C   /usr/bin/python3                  414MiB |
# |    4   N/A  N/A   3649819      C   /usr/bin/python3                  414MiB |
# |    5   N/A  N/A   3649821      C   /usr/bin/python3                  414MiB |
# |    6   N/A  N/A   3649825      C   /usr/bin/python3                  414MiB |
# |    7   N/A  N/A   3649827      C   /usr/bin/python3                  414MiB |
# +-----------------------------------------------------------------------------+

# %%
def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)
 
def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

# %%
# %%time
train_folds = []
val_folds = []
train_ys = []
val_ys = []

for i in range(5):
    print(f'Loading fold {i}')
    train_fold_d = delayed(pd.read_csv)(f'../input/xgtrain_fold_{i}_5X.csv.gz')
    train_fold = dd.from_delayed(train_fold_d)
    
    val_fold_d = delayed(pd.read_csv)(f'../input/xgval_fold_{i}_5X.csv.gz')
    val_fold = dd.from_delayed(val_fold_d)
    
    
    train_y = train_fold['target']
    train_fold = train_fold[train_fold.columns.difference(['target'])]
    
    val_y = val_fold['target']
    val_fold = val_fold[val_fold.columns.difference(['target'])]
    
    train_folds.append(train_fold)
    val_folds.append(val_fold)
    
    train_ys.append(train_y)
    val_ys.append(val_y)
# Out:
# Loading fold 0
# Loading fold 1
# Loading fold 2
# Loading fold 3
# Loading fold 4
# CPU times: user 1.38 s, sys: 1.63 s, total: 3.01 s
# Wall time: 37.9 s

# %%
# %%time
train = pd.read_csv('../input/train.csv.zip')

target = train['target'].values
target
# Out:
# CPU times: user 1.65 s, sys: 253 ms, total: 1.9 s
# Wall time: 1.77 s
# array([0, 0, 0, ..., 0, 0, 0])

# %%
train_oof = np.zeros((target.shape[0],))

num_round = 1000

def objective(trial):
        
    params = {
        'objective': trial.suggest_categorical('objective',['binary:logistic']),
        'tree_method': trial.suggest_categorical('tree_method',['gpu_hist']),  # 'gpu_hist','hist'
        'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
        'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
        'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
        #'n_estimators': trial.suggest_categorical('n_estimators', [1000]),
        'max_depth': trial.suggest_int('max_depth', 3, 35),
        #'random_state': trial.suggest_categorical('random_state', [24,48,2020]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1,300),
        'eval_metric': trial.suggest_categorical('eval_metric',['logloss']),

    }

    kf = KFold(5, shuffle=True, random_state=137)

    for i, (train_index, val_index) in enumerate(kf.split(train,target)):
        dtrain = xgb.dask.DaskDMatrix(client, train_folds[i].values, train_ys[i], enable_categorical=True)
        dval = xgb.dask.DaskDMatrix(client, val_folds[i].values, val_ys[i], enable_categorical=True)
        
        output = xgb.dask.train(client, params, dtrain, num_round)
        booster = output['booster']  # booster is the trained model
        booster.set_param({'predictor': 'gpu_predictor'})
        predictions = xgb.dask.predict(client, booster, dval)
        predictions = predictions.compute()
        train_oof[val_index] = predictions
        del dtrain, dval, output
        gc.collect()
        gc.collect()

    gini = gini_normalized(target, train_oof)
    
    return gini

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Setup the root logger.
logger.addHandler(logging.FileHandler("optuna_xgb_output_1.log", mode="w"))

optuna.logging.enable_propagation()  # Propagate logs to the root logger.
optuna.logging.disable_default_handler()  # Stop showing logs in sys.stderr.

study = optuna.create_study(storage="sqlite:///xgb_optuna_allstate_1.db", study_name="five_fold_optuna_xgb_1", direction='maximize')

# %%
# %%time
logger.info("Start optimization.")
study.optimize(objective, n_trials=3)
# Out:
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [16:48:30] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# [16:48:58] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# [16:49:23] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# [16:49:48] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# [16:50:12] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [16:50:37] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# [16:51:05] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# [16:51:33] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# [16:52:00] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# [16:52:27] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [16:52:54] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# [16:53:28] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# [16:54:01] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# [16:54:35] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# [16:55:09] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# 2023-09-07 16:55:36,006 - distributed.utils_perf - WARNING - full garbage collections took 73% CPU time recently (threshold: 10%)
# CPU times: user 50.4 s, sys: 26.5 s, total: 1min 16s
# Wall time: 7min 14s

# %%
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.head()
# Out:
#    number     value  params_alpha  params_colsample_bytree params_eval_metric  \
# 0       0  0.265787      0.147691                 0.514698            logloss
# 1       1  0.250456      0.002070                 0.918553            logloss
# 2       2  0.272139      0.007562                 0.982536            logloss
#
#    params_lambda  params_learning_rate  params_max_depth  \
# 0       1.311820              0.024202                35
# 1       0.001095              0.024384                16
# 2       0.439774              0.003817                22
#
#    params_min_child_weight params_objective  params_subsample  \
# 0                      251  binary:logistic          0.405729
# 1                      275  binary:logistic          0.729856
# 2                      245  binary:logistic          0.474967
#
#   params_tree_method     state
# 0           gpu_hist  COMPLETE
# 1           gpu_hist  COMPLETE
# 2           gpu_hist  COMPLETE

# %%
# %%time
study.optimize(objective, n_trials=5)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_1.csv', index=False)
df.head(8)
# Out:
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [16:55:44] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# 2023-09-07 16:56:03,968 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-07 16:56:04,065 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [16:56:11] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# 2023-09-07 16:56:31,722 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-07 16:56:31,821 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [16:56:39] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 16:56:59,526 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-07 16:56:59,624 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [16:57:07] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 16:57:27,172 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-07 16:57:27,270 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [16:57:34] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# 2023-09-07 16:57:54,818 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-07 16:57:54,917 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [16:58:03] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# 2023-09-07 16:58:32,925 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-07 16:58:33,025 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [16:58:40] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# 2023-09-07 16:59:11,889 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-07 16:59:11,995 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [16:59:19] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# 2023-09-07 16:59:50,522 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 16:59:50,621 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [16:59:58] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# 2023-09-07 17:00:28,518 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:00:28,617 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:00:36] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# 2023-09-07 17:01:06,460 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:01:06,559 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [17:01:14] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 17:01:38,877 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:01:38,976 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:01:46] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 17:02:10,626 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:02:10,726 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:02:18] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# 2023-09-07 17:02:42,500 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:02:42,602 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:02:50] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# 2023-09-07 17:03:14,439 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:03:14,543 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:03:22] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# 2023-09-07 17:03:47,139 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:03:47,242 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [17:03:55] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# 2023-09-07 17:04:18,148 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:04:18,252 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:04:25] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# 2023-09-07 17:04:48,428 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:04:48,531 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:04:56] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# 2023-09-07 17:05:18,932 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:05:19,037 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:05:26] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 17:05:49,128 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:05:49,229 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:05:56] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 17:06:19,102 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:06:19,203 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [17:06:27] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# 2023-09-07 17:06:41,214 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 17:06:41,316 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [17:06:48] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# 2023-09-07 17:07:02,850 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 17:07:02,952 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [17:07:10] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# 2023-09-07 17:07:25,244 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 17:07:25,346 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [17:07:33] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# 2023-09-07 17:07:46,949 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 17:07:47,052 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [17:07:54] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# 2023-09-07 17:08:08,507 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 17:08:08,609 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# CPU times: user 34 s, sys: 48.9 s, total: 1min 22s
# Wall time: 12min 32s
#    number     value  params_alpha  params_colsample_bytree params_eval_metric  \
# 0       0  0.265787      0.147691                 0.514698            logloss
# 1       1  0.250456      0.002070                 0.918553            logloss
# 2       2  0.272139      0.007562                 0.982536            logloss
# 3       3  0.217394      8.351180                 0.582607            logloss
# 4       4  0.266944      0.010888                 0.525752            logloss
# 5       5  0.272457      0.006724                 0.798969            logloss
# 6       6  0.167291      0.083198                 0.632627            logloss
# 7       7  0.208758      0.018195                 0.537393            logloss
#
#    params_lambda  params_learning_rate  params_max_depth  \
# 0       1.311820              0.024202                35
# 1       0.001095              0.024384                16
# 2       0.439774              0.003817                22
# 3       2.247182              0.042538                17
# 4       5.060227              0.001376                22
# 5       0.034626              0.011652                27
# 6       0.191721              0.090591                21
# 7       0.677840              0.066895                10
#
#    params_min_child_weight params_objective  params_subsample  \
# 0                      251  binary:logistic          0.405729
# 1                      275  binary:logistic          0.729856
# 2                      245  binary:logistic          0.474967
# 3                      210  binary:logistic          0.964056
# 4                       14  binary:logistic          0.648770
# 5                      250  binary:logistic          0.713822
# 6                      119  binary:logistic          0.570269
# 7                      155  binary:logistic          0.717660
#
#   params_tree_method     state
# 0           gpu_hist  COMPLETE
# 1           gpu_hist  COMPLETE
# 2           gpu_hist  COMPLETE
# 3           gpu_hist  COMPLETE
# 4           gpu_hist  COMPLETE
# 5           gpu_hist  COMPLETE
# 6           gpu_hist  COMPLETE
# 7           gpu_hist  COMPLETE

# %%
study.best_trial.params
# Out:
# {'objective': 'binary:logistic',
#  'tree_method': 'gpu_hist',
#  'lambda': 0.03462557447515088,
#  'alpha': 0.006724469780295505,
#  'colsample_bytree': 0.7989693088959113,
#  'subsample': 0.7138216244738642,
#  'learning_rate': 0.011652005325438634,
#  'max_depth': 27,
#  'min_child_weight': 250,
#  'eval_metric': 'logloss'}

# %%
df.value.max()
# Out:
# 0.27245707347014475

# %%
# %%time
study.optimize(objective, n_trials=100)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_1.csv', index=False)
df.head(20)
# Out:
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [17:08:16] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# 2023-09-07 17:08:39,794 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:08:39,896 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:08:47] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 17:09:10,232 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 17:09:10,337 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [17:09:17] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07
- distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:45:35,073 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [17:45:43] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 17:46:12,605 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:46:12,727 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [17:46:20] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 17:46:51,103 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:46:51,224 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [17:46:58] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# 2023-09-07 17:47:28,499 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:47:28,620 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [17:47:36] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# 2023-09-07 17:48:05,987 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:48:06,110 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [17:48:13] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# 2023-09-07 17:48:43,954 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:48:44,078 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [17:48:52] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# 2023-09-07 17:49:22,779 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:49:22,902 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [17:49:30] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# 2023-09-07 17:50:00,941 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:50:01,065 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [17:50:08] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# 2023-09-07 17:50:39,847 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:50:39,971 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [17:50:47] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 17:51:18,130 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:51:18,251 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [17:51:25] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 17:51:56,151 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 17:51:56,274 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# ...
# 2023-09-07 20:25:04,422 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:25:11] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 20:25:33,751 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:25:33,903 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:25:41] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 20:26:02,278 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:26:02,430 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:26:09] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# 2023-09-07 20:26:30,677 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:26:30,826 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:26:38] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# 2023-09-07 20:26:59,158 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:26:59,309 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [20:27:07] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# 2023-09-07 20:27:21,028 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:27:21,180 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:27:28] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# 2023-09-07 20:27:41,651 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:27:41,802 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:27:49] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# 2023-09-07 20:28:02,414 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:28:02,565 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:28:10] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# 2023-09-07 20:28:23,168 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:28:23,320 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:28:30] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 20:28:43,662 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:28:43,812 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [20:28:51] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 20:29:08,224 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:29:08,375 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:29:15] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# 2023-09-07 20:29:32,596 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:29:40] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# 2023-09-07 20:29:56,673 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:29:56,824 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:30:04] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# 2023-09-07 20:30:21,786 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:30:21,938 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:30:29] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# 2023-09-07 20:30:46,092 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:30:46,244 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [20:30:54] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# 2023-09-07 20:31:06,108 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:31:06,260 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:31:13] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# 2023-09-07 20:31:25,721 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:31:25,873 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:31:45,240 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:31:45,391 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:31:52] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 20:32:04,784 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:32:04,936 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [20:32:12] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# 2023-09-07 20:32:24,252 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 20:32:24,403 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# CPU times: user 12min 21s, sys: 11min 37s, total: 23min 59s
# Wall time: 3h 24min 15s
#     number     value  params_alpha  params_colsample_bytree  \
# 0        0  0.265787      0.147691                 0.514698
# 1        1  0.250456      0.002070                 0.918553
# 2        2  0.272139      0.007562                 0.982536
# 3        3  0.217394      8.351180                 0.582607
# 4        4  0.266944      0.010888                 0.525752
# 5        5  0.272457      0.006724                 0.798969
# 6        6  0.167291      0.083198                 0.632627
# 7        7  0.208758      0.018195                 0.537393
# 8        8  0.263502      0.023924                 0.958856
# 9        9  0.265101      0.002192                 0.588402
# 10      10  0.271638      0.001128                 0.360150
# 11      11  0.278146      0.005953                 0.809551
# 12      12  0.278076      0.004740                 0.806899
# 13      13  0.277929      0.001118                 0.778547
# 14      14  0.273728      0.063947                 0.799489
# 15      15  0.272143      0.004991                 0.712628
# 16      16  0.265592      0.004152                 0.875229
# 17      17  0.265278      0.028151                 0.869959
# 18      18  0.277401      0.003842                 0.701884
# 19      19  0.267295      0.013388                 0.877026
#
#    params_eval_metric  params_lambda  params_learning_rate  params_max_depth  \
# 0             logloss       1.311820              0.024202                35
# 1             logloss       0.001095              0.024384                16
# 2             logloss       0.439774              0.003817                22
# 3             logloss       2.247182              0.042538                17
# 4             logloss       5.060227              0.001376                22
# 5             logloss       0.034626              0.011652                27
# 6             logloss       0.191721              0.090591                21
# 7             logloss       0.677840              0.066895                10
# 8             logloss       4.026531              0.002067                24
# 9             logloss       0.001377              0.031837                 8
# 10            logloss       0.034416              0.008775                32
# 11            logloss       0.052444              0.005797                28
# 12            logloss       0.028319              0.008742                28
# 13            logloss       0.043606              0.005621                29
# 14            logloss       0.103880              0.011683                28
# 15            logloss       0.006923              0.003134                35
# 16            logloss       0.012876              0.006649                 3
# 17            logloss       0.236193              0.015294                31
# 18            logloss       0.089552              0.004987                27
# 19            logloss       0.011593              0.007907                14
#
#     params_min_child_weight params_objective  params_subsample  \
# 0                       251  binary:logistic          0.405729
# 1                       275  binary:logistic          0.729856
# 2                       245  binary:logistic          0.474967
# 3                       210  binary:logistic          0.964056
# 4                        14  binary:logistic          0.648770
# 5                       250  binary:logistic          0.713822
# 6                       119  binary:logistic          0.570269
# 7                       155  binary:logistic          0.717660
# 8                       286  binary:logistic          0.812355
# 9                       182  binary:logistic          0.758519
# 10                       86  binary:logistic          0.877452
# 11                      237  binary:logistic          0.568800
# 12                      214  binary:logistic          0.613187
# 13                      205  binary:logistic          0.592913
# 14                      209  binary:logistic          0.550819
# 15                      160  binary:logistic          0.637848
# 16                      119  binary:logistic          0.496145
# 17                      226  binary:logistic          0.656009
# 18                      298  binary:logistic          0.517442
# 19                       38  binary:logistic          0.615805
#
#    params_tree_method     state
# 0            gpu_hist  COMPLETE
# 1            gpu_hist  COMPLETE
# 2            gpu_hist  COMPLETE
# 3            gpu_hist  COMPLETE
# 4            gpu_hist  COMPLETE
# 5            gpu_hist  COMPLETE
# 6            gpu_hist  COMPLETE
# 7            gpu_hist  COMPLETE
# 8            gpu_hist  COMPLETE
# 9            gpu_hist  COMPLETE
# 10           gpu_hist  COMPLETE
# 11           gpu_hist  COMPLETE
# 12           gpu_hist  COMPLETE
# 13           gpu_hist  COMPLETE
# 14           gpu_hist  COMPLETE
# 15           gpu_hist  COMPLETE
# 16           gpu_hist  COMPLETE
# 17           gpu_hist  COMPLETE
# 18           gpu_hist  COMPLETE
# 19           gpu_hist  COMPLETE

# %%
df.value.max()
# Out:
# 0.28356327394129066

# %%
study.best_trial.params
# Out:
# {'objective': 'binary:logistic',
#  'tree_method': 'gpu_hist',
#  'lambda': 0.002266035456133577,
#  'alpha': 0.01852336999227343,
#  'colsample_bytree': 0.6218961625493891,
#  'subsample': 0.47593096138855273,
#  'learning_rate': 0.009910587990510247,
#  'max_depth': 8,
#  'min_child_weight': 292,
#  'eval_metric': 'logloss'}

# %%
# %%time
study.optimize(objective, n_trials=900)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_1.csv', index=False)
df.head(20)
# Out:
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [20:32:32] task [xgboost.dask-3]:tcp://127.0.0.1:33869 got new rank 0
# 2023-09-07 20:32:44,669 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# 2023-09-07 20:32:44,824 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# [20:32:52] task [xgboost.dask-0]:tcp://127.0.0.1:46439 got new rank 0
# 2023-09-07 20:33:05,496 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# 2023-09-07 20:33:05,648 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# [20:33:13] task [xgboost.dask-1]:tcp://127.0.0.1:45947 got new rank 0
# 2023-09-07 20:33:25,452 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# 2023-09-07 20:33:25,604 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# [20:33:33] task [xgboost.dask-4]:tcp://127.0.0.1:43029 got new rank 0
# 2023-09-07 20:33:45,519 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# 2023-09-07 20:33:45,672 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# [20:33:53] task [xgboost.dask-2]:tcp://127.0.0.1:41791 got new rank 0
# 2023-09-07 20:34:05,454 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# 2023-09-07 20:34:05,607 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3649481/1212525843.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3649481/1212525843.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3649481/1212525843.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3649481/1212525843.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [20:34:13] task [xgboost.dask-7]:tcp://127.0.0.1:38135 got new rank 0
# 2023-09-07 20:34:28,028 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# 2023-09-07 20:34:28,180 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# [20:34:35] task [xgboost.dask-5]:tcp://127.0.0.1:35635 got new rank 0
# 2023-09-07 20:34:50,092 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# 2023-09-07 20:34:50,245 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# [20:34:57] task [xgboost.dask-6]:tcp://127.0.0.1:35583 got new rank 0
# 2023-09-07 20:35:12,193 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# 2023-09-07 20:35:12,345 - distributed.utils_perf - WARNING - full garbage collections took 80% CPU time recently (threshold: 10%)
# [20