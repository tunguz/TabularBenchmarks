# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2023-09-08T07:27:27.992101-07:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.14.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 5.15.0-1029-nvidia
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 256
# Architecture: 64bit

# %%
# %watermark --gpu
# Out:
# GPU Info:
#   GPU 0: NVIDIA A100-SXM4-80GB
#   GPU 1: NVIDIA A100-SXM4-80GB
#   GPU 2: NVIDIA A100-SXM4-80GB
#   GPU 3: NVIDIA A100-SXM4-80GB
#   GPU 4: NVIDIA A100-SXM4-80GB
#   GPU 5: NVIDIA A100-SXM4-80GB
#   GPU 6: NVIDIA A100-SXM4-80GB
#   GPU 7: NVIDIA A100-SXM4-80GB

# %%
from dask.distributed import Client
from dask_cuda import LocalCUDACluster
from dask import dataframe as dd
from dask.delayed import delayed
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

import optuna
import gc
import logging

# %%
# %watermark --iversions
# Out:
# xgboost: 1.7.6
# numpy  : 1.24.4
# optuna : 3.3.0
# logging: 0.5.1.2
# dask   : 2023.3.2
# pandas : 1.5.3

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-80GB (UUID: GPU-cf1d9297-d9c3-6b2a-8afa-e63e4b5abb2d)
# GPU 1: NVIDIA A100-SXM4-80GB (UUID: GPU-6d18acdc-2136-40ac-5eeb-724e81476385)
# GPU 2: NVIDIA A100-SXM4-80GB (UUID: GPU-a87c7d38-52d2-befc-e2de-3cf90f75d6eb)
# GPU 3: NVIDIA A100-SXM4-80GB (UUID: GPU-8e290e7b-dec5-1828-2ec2-a6930ecd4b5b)
# GPU 4: NVIDIA A100-SXM4-80GB (UUID: GPU-36f4174f-2697-e22e-3ae5-0d30e814c4f1)
# GPU 5: NVIDIA A100-SXM4-80GB (UUID: GPU-d0929bb4-8c8c-8418-70d2-f658013f4b33)
# GPU 6: NVIDIA A100-SXM4-80GB (UUID: GPU-78f54132-3566-5a8c-b51b-fb3cc695d648)
# GPU 7: NVIDIA A100-SXM4-80GB (UUID: GPU-61b9f63d-cb20-77e8-8b22-40f40fbb8715)

# %%
cluster = LocalCUDACluster(n_workers=8)
client = Client(cluster)
# Out:
# 2023-09-08 07:27:33,872 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-08 07:27:33,872 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-08 07:27:33,875 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-08 07:27:33,876 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-08 07:27:33,882 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-08 07:27:33,882 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-08 07:27:33,882 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-08 07:27:33,882 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-08 07:27:33,884 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-08 07:27:33,884 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-08 07:27:33,884 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-08 07:27:33,884 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-08 07:27:33,887 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-08 07:27:33,887 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-08 07:27:33,888 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-08 07:27:33,888 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize

# %%
# !nvidia-smi
# Out:
# Fri Sep  8 07:27:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   34C    P0    70W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   31C    P0    67W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-SXM...  On   | 00000000:47:00.0 Off |                    0 |
# | N/A   31C    P0    66W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-SXM...  On   | 00000000:4E:00.0 Off |                    0 |
# | N/A   32C    P0    67W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100-SXM...  On   | 00000000:87:00.0 Off |                    0 |
# | N/A   37C    P0    66W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100-SXM...  On   | 00000000:90:00.0 Off |                    0 |
# | N/A   35C    P0    69W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100-SXM...  On   | 00000000:B7:00.0 Off |                    0 |
# | N/A   34C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100-SXM...  On   | 00000000:BD:00.0 Off |                    0 |
# | N/A   35C    P0    67W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A    244141      C   /usr/bin/python3                  414MiB |
# |    1   N/A  N/A    244145      C   /usr/bin/python3                  414MiB |
# |    2   N/A  N/A    244150      C   /usr/bin/python3                  414MiB |
# |    3   N/A  N/A    244148      C   /usr/bin/python3                  414MiB |
# |    4   N/A  N/A    244154      C   /usr/bin/python3                  414MiB |
# |    5   N/A  N/A    244156      C   /usr/bin/python3                  414MiB |
# |    6   N/A  N/A    244160      C   /usr/bin/python3                  414MiB |
# |    7   N/A  N/A    244162      C   /usr/bin/python3                  414MiB |
# +-----------------------------------------------------------------------------+

# %%
def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)
 
def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

# %%
# %%time
train_folds = []
val_folds = []
train_ys = []
val_ys = []

for i in range(5):
    print(f'Loading fold {i}')
    train_fold_d = delayed(pd.read_csv)(f'../input/xgtrain_fold_{i}_5X.csv.gz')
    train_fold = dd.from_delayed(train_fold_d)
    
    val_fold_d = delayed(pd.read_csv)(f'../input/xgval_fold_{i}_5X.csv.gz')
    val_fold = dd.from_delayed(val_fold_d)
    
    
    train_y = train_fold['target']
    train_fold = train_fold[train_fold.columns.difference(['target'])]
    
    val_y = val_fold['target']
    val_fold = val_fold[val_fold.columns.difference(['target'])]
    
    train_folds.append(train_fold)
    val_folds.append(val_fold)
    
    train_ys.append(train_y)
    val_ys.append(val_y)
# Out:
# Loading fold 0
# Loading fold 1
# Loading fold 2
# Loading fold 3
# Loading fold 4
# CPU times: user 1.53 s, sys: 1.51 s, total: 3.04 s
# Wall time: 37.9 s

# %%
# %%time
train = pd.read_csv('../input/train.csv.zip')

target = train['target'].values
target
# Out:
# CPU times: user 1.62 s, sys: 381 ms, total: 2 s
# Wall time: 1.81 s
# array([0, 0, 0, ..., 0, 0, 0])

# %%
train_oof = np.zeros((target.shape[0],))

num_round = 1000

def objective(trial):
        
    params = {
        'objective': trial.suggest_categorical('objective',['binary:logistic']),
        'tree_method': trial.suggest_categorical('tree_method',['gpu_hist']),  # 'gpu_hist','hist'
        'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
        'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
        'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
        #'n_estimators': trial.suggest_categorical('n_estimators', [1000]),
        'max_depth': trial.suggest_int('max_depth', 3, 25),
        #'random_state': trial.suggest_categorical('random_state', [24,48,2020]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1,300),
        'eval_metric': trial.suggest_categorical('eval_metric',['logloss']),

    }

    kf = KFold(5, shuffle=True, random_state=137)

    for i, (train_index, val_index) in enumerate(kf.split(train,target)):
        dtrain = xgb.dask.DaskDMatrix(client, train_folds[i].values, train_ys[i], enable_categorical=True)
        dval = xgb.dask.DaskDMatrix(client, val_folds[i].values, val_ys[i], enable_categorical=True)
        
        output = xgb.dask.train(client, params, dtrain, num_round)
        booster = output['booster']  # booster is the trained model
        booster.set_param({'predictor': 'gpu_predictor'})
        predictions = xgb.dask.predict(client, booster, dval)
        predictions = predictions.compute()
        train_oof[val_index] = predictions
        del dtrain, dval, output
        gc.collect()
        gc.collect()

    gini = gini_normalized(target, train_oof)
    
    return gini

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Setup the root logger.
logger.addHandler(logging.FileHandler("optuna_xgb_output_2.log", mode="w"))

optuna.logging.enable_propagation()  # Propagate logs to the root logger.
optuna.logging.disable_default_handler()  # Stop showing logs in sys.stderr.

study = optuna.create_study(storage="sqlite:///xgb_optuna_allstate_2.db", study_name="five_fold_optuna_xgb_2", direction='maximize')

# %%
# %%time
logger.info("Start optimization.")
study.optimize(objective, n_trials=3)
# Out:
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:28:30] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# [07:28:50] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# [07:29:09] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# [07:29:27] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# [07:29:44] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:30:02] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# [07:30:21] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# [07:30:40] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# [07:30:59] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# [07:31:18] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:31:37] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# [07:32:03] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# [07:32:29] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# [07:32:55] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# [07:33:21] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 07:33:40,046 - distributed.utils_perf - WARNING - full garbage collections took 72% CPU time recently (threshold: 10%)
# CPU times: user 1min, sys: 16.8 s, total: 1min 17s
# Wall time: 5min 18s

# %%
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.head()
# Out:
#    number     value  params_alpha  params_colsample_bytree params_eval_metric  \
# 0       0  0.279015      0.101644                 0.799539            logloss
# 1       1  0.206835      7.410294                 0.751174            logloss
# 2       2  0.276148      2.521110                 0.489428            logloss
#
#    params_lambda  params_learning_rate  params_max_depth  \
# 0       1.469876              0.020145                 6
# 1       2.073095              0.088018                 7
# 2       0.554493              0.004287                16
#
#    params_min_child_weight params_objective  params_subsample  \
# 0                       18  binary:logistic          0.539325
# 1                       51  binary:logistic          0.988258
# 2                      290  binary:logistic          0.717498
#
#   params_tree_method     state
# 0           gpu_hist  COMPLETE
# 1           gpu_hist  COMPLETE
# 2           gpu_hist  COMPLETE

# %%
# %%time
study.optimize(objective, n_trials=5)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_2.csv', index=False)
df.head(8)
# Out:
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:34:33] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 07:34:46,541 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:34:46,638 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:34:54] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# 2023-09-08 07:35:07,865 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:35:07,962 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:35:15] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# 2023-09-08 07:35:29,259 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:35:29,356 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:35:37] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# 2023-09-08 07:35:50,414 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:35:50,512 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:35:58] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# 2023-09-08 07:36:11,770 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:36:11,868 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:36:20] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# 2023-09-08 07:36:37,420 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:36:37,518 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:36:45] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# 2023-09-08 07:37:02,512 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:37:02,610 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:37:10] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 07:37:27,623 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:37:27,723 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:37:35] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 07:37:52,931 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:37:53,029 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:38:00] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# 2023-09-08 07:38:17,951 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:38:18,053 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:38:26] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# 2023-09-08 07:38:51,762 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:38:51,865 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# [07:38:59] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# 2023-09-08 07:39:24,138 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# 2023-09-08 07:39:24,240 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:39:32] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# 2023-09-08 07:39:56,909 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:39:57,011 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:40:04] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# 2023-09-08 07:40:29,476 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:40:29,579 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:40:37] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# 2023-09-08 07:41:01,676 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:41:01,779 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:41:10] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 07:41:23,576 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:41:23,681 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:41:31] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 07:41:45,034 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:41:45,138 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:41:52] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# 2023-09-08 07:42:06,284 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:42:06,387 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:42:14] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# 2023-09-08 07:42:27,912 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:42:28,016 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:42:35] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# 2023-09-08 07:42:49,298 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:42:49,403 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:42:57] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# 2023-09-08 07:43:30,159 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:43:30,264 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:43:37] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# 2023-09-08 07:44:10,543 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:44:10,646 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:44:18] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# 2023-09-08 07:44:50,340 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:44:50,444 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:44:58] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 07:45:31,923 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:45:32,028 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:45:39] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 07:46:12,126 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:46:12,230 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# CPU times: user 59.4 s, sys: 41.5 s, total: 1min 40s
# Wall time: 11min 47s
#    number     value  params_alpha  params_colsample_bytree params_eval_metric  \
# 0       0  0.279015      0.101644                 0.799539            logloss
# 1       1  0.206835      7.410294                 0.751174            logloss
# 2       2  0.276148      2.521110                 0.489428            logloss
# 3       3  0.189467      0.022334                 0.719523            logloss
# 4       4  0.255407      0.230446                 0.357887            logloss
# 5       5  0.271643      0.949032                 0.566390            logloss
# 6       6  0.248353      2.229799                 0.446748            logloss
# 7       7  0.274697      0.010156                 0.645108            logloss
#
#    params_lambda  params_learning_rate  params_max_depth  \
# 0       1.469876              0.020145                 6
# 1       2.073095              0.088018                 7
# 2       0.554493              0.004287                16
# 3       0.002333              0.089806                10
# 4       0.002049              0.028042                13
# 5       3.371826              0.002190                19
# 6       0.032399              0.040828                10
# 7       0.005530              0.004147                12
#
#    params_min_child_weight params_objective  params_subsample  \
# 0                       18  binary:logistic          0.539325
# 1                       51  binary:logistic          0.988258
# 2                      290  binary:logistic          0.717498
# 3                      194  binary:logistic          0.970214
# 4                      197  binary:logistic          0.604751
# 5                      156  binary:logistic          0.876918
# 6                      167  binary:logistic          0.437375
# 7                       38  binary:logistic          0.593388
#
#   params_tree_method     state
# 0           gpu_hist  COMPLETE
# 1           gpu_hist  COMPLETE
# 2           gpu_hist  COMPLETE
# 3           gpu_hist  COMPLETE
# 4           gpu_hist  COMPLETE
# 5           gpu_hist  COMPLETE
# 6           gpu_hist  COMPLETE
# 7           gpu_hist  COMPLETE

# %%
study.best_trial.params
# Out:
# {'objective': 'binary:logistic',
#  'tree_method': 'gpu_hist',
#  'lambda': 1.4698756145809344,
#  'alpha': 0.10164370841935841,
#  'colsample_bytree': 0.7995392666832839,
#  'subsample': 0.5393248559012488,
#  'learning_rate': 0.02014455774890158,
#  'max_depth': 6,
#  'min_child_weight': 18,
#  'eval_metric': 'logloss'}

# %%
df.value.max()
# Out:
# 0.2790151032993089

# %%
# %%time
study.optimize(objective, n_trials=17)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_2.csv', index=False)
df.head(20)
# Out:
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:47:44] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# 2023-09-08 07:48:03,220 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:48:03,326 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:48:10] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# 2023-09-08 07:48:30,137 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:48:30,244 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:48:37] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# 2023-09-08 07:48:57,529 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:48:57,636 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:49:05] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# 2023-09-08 07:49:24,487 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:49:24,593 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:49:32] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# 2023-09-08 07:49:51,284 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:49:51,389 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:49:59] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# 2023-09-08 07:50:09,649 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:50:09,754 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:50:17] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 07:50:27,579 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:50:27,686 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:50:35] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 07:50:45,313 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:50:45,422 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:50:53] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# 2023-09-08 07:51:03,329 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:51:03,438 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:51:11] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# 2023-09-08 07:51:21,171 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:51:21,279 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:51:29] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# 2023-09-08 07:51:36,451 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:51:36,564 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:51:44] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# 2023-09-08 07:51:51,093 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:51:51,204 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:51:58] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# 2023-09-08 07:52:05,863 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:52:05,970 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:52:14] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# 2023-09-08 07:52:21,266 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:52:21,374 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:52:29] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 07:52:36,132 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:52:36,244 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:52:44] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 07:53:07,732 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:53:07,840 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:53:15] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# 2023-09-08 07:53:38,554 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:53:38,662 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:53:46] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# 2023-09-08 07:54:09,549 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:54:09,656 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:54:17] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# 2023-09-08 07:54:40,596 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:54:40,703 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:54:48] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# 2023-09-08 07:55:11,618 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:55:11,726 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:55:19] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# 2023-09-08 07:55:43,874 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:55:43,982 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:55:51] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# 2023-09-08 07:56:15,526 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:56:15,633 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:56:23] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 07:56:47,473 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 07:56:47,581 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:56:55] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 07:57:19,388 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:57:19,496 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:57:27] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# 2023-09-08 07:57:51,125 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:57:51,233 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:57:59] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# 2023-09-08 07:58:35,693 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:58:35,801 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:58:43] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# 2023-09-08 07:59:20,001 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 07:59:20,109 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:59:27] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# 2023-09-08 08:00:04,257 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 08:00:04,368 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:00:11] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# 2023-09-08 08:00:47,800 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 08:00:47,910 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:00:55] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# 2023-09-08 08:01:31,936 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 08:01:32,045 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:01:40] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 08:02:01,498 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 08:02:01,608 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:02:09] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 08:02:30,238 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 08:02:30,348 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:02:38] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0
# 2023-09-08 08:02:59,360 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 08:02:59,470 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:03:07] task [xgboost.dask-1]:tcp://127.0.0.1:36651 got new rank 0
# 2023-09-08 08:03:28,432 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 08:03:28,543 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:03:36] task [xgboost.dask-3]:tcp://127.0.0.1:36237 got new rank 0
# 2023-09-08 08:03:57,402 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 08:03:57,514 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:04:05] task [xgboost.dask-2]:tcp://127.0.0.1:35285 got new rank 0
# 2023-09-08 08:04:33,799 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-08 08:04:33,914 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:04:41] task [xgboost.dask-6]:tcp://127.0.0.1:34519 got new rank 0
# 2023-09-08 08:05:09,821 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 08:05:09,932 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:05:17] task [xgboost.dask-5]:tcp://127.0.0.1:46139 got new rank 0
# 2023-09-08 08:05:45,840 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 08:05:45,952 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:05:53] task [xgboost.dask-0]:tcp://127.0.0.1:44397 got new rank 0
# 2023-09-08 08:06:21,866 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 08:06:21,978 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:06:29] task [xgboost.dask-7]:tcp://127.0.0.1:42405 got new rank 0
# 2023-09-08 08:06:57,972 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-08 08:06:58,084 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# /tmp/ipykernel_243916/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_243916/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_243916/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_243916/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:07:06] task [xgboost.dask-4]:tcp://127.0.0.1:39497 got new rank 0

# %%
df.value.max()

# %%
study.best_trial.params

# %%
# %%time
study.optimize(objective, n_trials=100)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_2.csv', index=False)
df.head(20)
