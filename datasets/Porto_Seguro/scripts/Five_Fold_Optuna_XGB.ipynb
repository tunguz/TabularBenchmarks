# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2023-09-07T07:33:19.114360-07:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.14.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 5.15.0-1029-nvidia
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 256
# Architecture: 64bit

# %%
# %watermark --gpu
# Out:
# GPU Info:
#   GPU 0: NVIDIA A100-SXM4-80GB
#   GPU 1: NVIDIA A100-SXM4-80GB
#   GPU 2: NVIDIA A100-SXM4-80GB
#   GPU 3: NVIDIA A100-SXM4-80GB
#   GPU 4: NVIDIA A100-SXM4-80GB
#   GPU 5: NVIDIA A100-SXM4-80GB
#   GPU 6: NVIDIA A100-SXM4-80GB
#   GPU 7: NVIDIA A100-SXM4-80GB

# %%
from dask.distributed import Client
from dask_cuda import LocalCUDACluster
from dask import dataframe as dd
from dask.delayed import delayed
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

import optuna
import gc
import logging

# %%
# %watermark --iversions
# Out:
# logging: 0.5.1.2
# numpy  : 1.24.4
# pandas : 1.5.3
# xgboost: 1.7.6
# optuna : 3.3.0
# dask   : 2023.3.2

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-80GB (UUID: GPU-cf1d9297-d9c3-6b2a-8afa-e63e4b5abb2d)
# GPU 1: NVIDIA A100-SXM4-80GB (UUID: GPU-6d18acdc-2136-40ac-5eeb-724e81476385)
# GPU 2: NVIDIA A100-SXM4-80GB (UUID: GPU-a87c7d38-52d2-befc-e2de-3cf90f75d6eb)
# GPU 3: NVIDIA A100-SXM4-80GB (UUID: GPU-8e290e7b-dec5-1828-2ec2-a6930ecd4b5b)
# GPU 4: NVIDIA A100-SXM4-80GB (UUID: GPU-36f4174f-2697-e22e-3ae5-0d30e814c4f1)
# GPU 5: NVIDIA A100-SXM4-80GB (UUID: GPU-d0929bb4-8c8c-8418-70d2-f658013f4b33)
# GPU 6: NVIDIA A100-SXM4-80GB (UUID: GPU-78f54132-3566-5a8c-b51b-fb3cc695d648)
# GPU 7: NVIDIA A100-SXM4-80GB (UUID: GPU-61b9f63d-cb20-77e8-8b22-40f40fbb8715)

# %%
cluster = LocalCUDACluster(n_workers=8)
client = Client(cluster)
# Out:
# 2023-09-07 07:34:51,401 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 07:34:51,401 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 07:34:51,405 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 07:34:51,405 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 07:34:51,405 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 07:34:51,406 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 07:34:51,411 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 07:34:51,411 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 07:34:51,412 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 07:34:51,412 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 07:34:51,418 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 07:34:51,418 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 07:34:51,419 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 07:34:51,419 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-09-07 07:34:51,421 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-09-07 07:34:51,421 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize

# %%
# !nvidia-smi
# Out:
# Thu Sep  7 07:35:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   34C    P0    70W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   31C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-SXM...  On   | 00000000:47:00.0 Off |                    0 |
# | N/A   32C    P0    66W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-SXM...  On   | 00000000:4E:00.0 Off |                    0 |
# | N/A   33C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100-SXM...  On   | 00000000:87:00.0 Off |                    0 |
# | N/A   38C    P0    66W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100-SXM...  On   | 00000000:90:00.0 Off |                    0 |
# | N/A   37C    P0    70W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100-SXM...  On   | 00000000:B7:00.0 Off |                    0 |
# | N/A   36C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100-SXM...  On   | 00000000:BD:00.0 Off |                    0 |
# | N/A   38C    P0    69W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A   3143082      C   /usr/bin/python3                  414MiB |
# |    1   N/A  N/A   3143085      C   /usr/bin/python3                  414MiB |
# |    2   N/A  N/A   3143089      C   /usr/bin/python3                  414MiB |
# |    3   N/A  N/A   3143092      C   /usr/bin/python3                  414MiB |
# |    4   N/A  N/A   3143095      C   /usr/bin/python3                  414MiB |
# |    5   N/A  N/A   3143098      C   /usr/bin/python3                  414MiB |
# |    6   N/A  N/A   3143101      C   /usr/bin/python3                  414MiB |
# |    7   N/A  N/A   3143103      C   /usr/bin/python3                  414MiB |
# +-----------------------------------------------------------------------------+

# %%
def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)
 
def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

# %%
train_folds = []
val_folds = []
train_ys = []
val_ys = []

for i in range(5):
    print(f'Loading fold {i}')
    train_fold_d = delayed(pd.read_csv)(f'../input/xgtrain_fold_{i}.csv.gz')
    train_fold = dd.from_delayed(train_fold_d)
    
    val_fold_d = delayed(pd.read_csv)(f'../input/xgval_fold_{i}.csv.gz')
    val_fold = dd.from_delayed(val_fold_d)
    
    
    train_y = train_fold['target']
    train_fold = train_fold[train_fold.columns.difference(['target'])]
    
    val_y = val_fold['target']
    val_fold = val_fold[val_fold.columns.difference(['target'])]
    
    train_folds.append(train_fold)
    val_folds.append(val_fold)
    
    train_ys.append(train_y)
    val_ys.append(val_y)
# Out:
# Loading fold 0
# Loading fold 1
# Loading fold 2
# Loading fold 3
# Loading fold 4

# %%
train = pd.read_csv('../input/train.csv.zip')

target = train['target'].values
target
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
train_oof = np.zeros((target.shape[0],))

num_round = 1000

def objective(trial):
        
    params = {
        'objective': trial.suggest_categorical('objective',['binary:logistic']),
        'tree_method': trial.suggest_categorical('tree_method',['gpu_hist']),  # 'gpu_hist','hist'
        'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
        'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
        'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
        #'n_estimators': trial.suggest_categorical('n_estimators', [1000]),
        'max_depth': trial.suggest_int('max_depth', 3, 25),
        #'random_state': trial.suggest_categorical('random_state', [24,48,2020]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1,300),
        'eval_metric': trial.suggest_categorical('eval_metric',['logloss']),

    }

    kf = KFold(5, shuffle=True, random_state=137)

    for i, (train_index, val_index) in enumerate(kf.split(train,target)):
        dtrain = xgb.dask.DaskDMatrix(client, train_folds[i].values, train_ys[i], enable_categorical=True)
        dval = xgb.dask.DaskDMatrix(client, val_folds[i].values, val_ys[i], enable_categorical=True)
        
        output = xgb.dask.train(client, params, dtrain, num_round)
        booster = output['booster']  # booster is the trained model
        booster.set_param({'predictor': 'gpu_predictor'})
        predictions = xgb.dask.predict(client, booster, dval)
        predictions = predictions.compute()
        train_oof[val_index] = predictions
        del dtrain, dval, output
        gc.collect()
        gc.collect()

    gini = gini_normalized(target, train_oof)
    
    return gini

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Setup the root logger.
logger.addHandler(logging.FileHandler("optuna_xgb_output_0.log", mode="w"))

optuna.logging.enable_propagation()  # Propagate logs to the root logger.
optuna.logging.disable_default_handler()  # Stop showing logs in sys.stderr.

study = optuna.create_study(storage="sqlite:///xgb_optuna_allstate_0.db", study_name="five_fold_optuna_xgb_0", direction='maximize')

# %%
# %%time
logger.info("Start optimization.")
study.optimize(objective, n_trials=3)
# Out:
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:44:46] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# [07:44:55] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# [07:45:03] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# [07:45:11] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# [07:45:18] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:45:26] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# [07:45:34] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# [07:45:42] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# [07:45:50] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# [07:45:57] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:46:05] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# [07:46:13] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# [07:46:20] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# [07:46:28] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# [07:46:35] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 07:46:40,930 - distributed.utils_perf - WARNING - full garbage collections took 74% CPU time recently (threshold: 10%)
# CPU times: user 57.1 s, sys: 5.77 s, total: 1min 2s
# Wall time: 1min 57s

# %%
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.head()
# Out:
#    number     value  params_alpha  params_colsample_bytree params_eval_metric  \
# 0       0  0.260580      0.518387                 0.588129            logloss
# 1       1  0.272333      0.554771                 0.386440            logloss
# 2       2  0.273310      0.001337                 0.321878            logloss
#
#    params_lambda  params_learning_rate  params_max_depth  \
# 0       0.803620              0.001024                19
# 1       0.515043              0.004684                19
# 2       0.224638              0.035482                25
#
#    params_min_child_weight params_objective  params_subsample  \
# 0                       73  binary:logistic          0.734509
# 1                      226  binary:logistic          0.740431
# 2                      235  binary:logistic          0.647692
#
#   params_tree_method     state
# 0           gpu_hist  COMPLETE
# 1           gpu_hist  COMPLETE
# 2           gpu_hist  COMPLETE

# %%
# %%time
study.optimize(objective, n_trials=5)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_0.csv', index=False)
df.head(8)
# Out:
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:47:32] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 07:48:23,380 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:48:23,480 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:48:25] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 07:49:18,304 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:49:18,403 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:49:20] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 07:50:14,277 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:50:14,377 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:50:16] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 07:51:18,388 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:51:18,490 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:51:20] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 07:52:10,373 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:52:10,475 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:52:12] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 07:52:19,145 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:52:19,247 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:52:21] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 07:52:27,459 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:52:27,562 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:52:29] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 07:52:35,816 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:52:35,918 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:52:37] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 07:52:43,937 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:52:44,044 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:52:45] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 07:52:52,132 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:52:52,236 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:52:54] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 07:53:03,162 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:53:03,263 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:53:05] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 07:53:13,866 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:53:13,970 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:53:15] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 07:53:24,612 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:53:24,715 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:53:26] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 07:53:35,256 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:53:35,358 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:53:37] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 07:53:45,955 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:53:46,058 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:53:48] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 07:54:04,075 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:54:04,176 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:54:06] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 07:54:21,310 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:54:21,416 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:54:23] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 07:54:38,923 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 07:54:39,024 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:54:40] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 07:54:56,207 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 07:54:56,309 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:54:58] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 07:55:13,680 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 07:55:13,787 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:55:16] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 07:55:30,998 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 07:55:31,102 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:55:33] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 07:55:47,784 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 07:55:47,886 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:55:49] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 07:56:04,669 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 07:56:04,772 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:56:06] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 07:56:21,458 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 07:56:21,563 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [07:56:23] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 07:56:38,002 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 07:56:38,108 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# CPU times: user 35.4 s, sys: 31 s, total: 1min 6s
# Wall time: 9min 8s
#    number     value  params_alpha  params_colsample_bytree params_eval_metric  \
# 0       0  0.260580      0.518387                 0.588129            logloss
# 1       1  0.272333      0.554771                 0.386440            logloss
# 2       2  0.273310      0.001337                 0.321878            logloss
# 3       3  0.213742      0.475032                 0.907356            logloss
# 4       4  0.250605      7.983068                 0.797204            logloss
# 5       5  0.279674      0.039072                 0.650555            logloss
# 6       6  0.270530      0.040732                 0.589670            logloss
# 7       7  0.231640      8.520712                 0.554478            logloss
#
#    params_lambda  params_learning_rate  params_max_depth  \
# 0       0.803620              0.001024                19
# 1       0.515043              0.004684                19
# 2       0.224638              0.035482                25
# 3       0.025882              0.019162                21
# 4       1.452732              0.037789                 8
# 5       3.588531              0.005713                16
# 6       0.035789              0.001149                24
# 7       2.060507              0.039615                23
#
#    params_min_child_weight params_objective  params_subsample  \
# 0                       73  binary:logistic          0.734509
# 1                      226  binary:logistic          0.740431
# 2                      235  binary:logistic          0.647692
# 3                        5  binary:logistic          0.939027
# 4                       12  binary:logistic          0.532211
# 5                       70  binary:logistic          0.882057
# 6                      155  binary:logistic          0.813833
# 7                       10  binary:logistic          0.537622
#
#   params_tree_method     state
# 0           gpu_hist  COMPLETE
# 1           gpu_hist  COMPLETE
# 2           gpu_hist  COMPLETE
# 3           gpu_hist  COMPLETE
# 4           gpu_hist  COMPLETE
# 5           gpu_hist  COMPLETE
# 6           gpu_hist  COMPLETE
# 7           gpu_hist  COMPLETE

# %%
study.best_trial.params
# Out:
# {'objective': 'binary:logistic',
#  'tree_method': 'gpu_hist',
#  'lambda': 3.58853089923261,
#  'alpha': 0.03907190647684065,
#  'colsample_bytree': 0.6505547297793564,
#  'subsample': 0.8820571272532136,
#  'learning_rate': 0.005713381470116442,
#  'max_depth': 16,
#  'min_child_weight': 70,
#  'eval_metric': 'logloss'}

# %%
df.value.max()
# Out:
# 0.2796737747509847

# %%
# %%time
study.optimize(objective, n_trials=100)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_0.csv', index=False)
df.head(20)
# Out:
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [07:57:57] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 07:58:36,513 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:58:36,617 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:58:38] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 07:59:18,236 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 07:59:18,340 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [07:59:20] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:00:00,136 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 08:00:00,243 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:00:02] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:00:42,302 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 08:00:42,408 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:00:44] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:01:24,076 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 08:01:24,183 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:01:26] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:01:39,405 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 08:01:39,512 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:01:41] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:01:54,371 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 08:01:54,481 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:01:56] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:02:09,066 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:02:09,178 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:02:11] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:02:23,869 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:02:23,978 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:02:25] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:02:39,041 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:02:39,151 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:02:41] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:02:46,160 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 08:02:46,272 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# [08:02:48] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:02:52,774 - distributed.utils_perf - WARNING - full garbage collections took 75% CPU time recently (threshold: 10%)
# 2023-09-07 08:02:52,884 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:02:54] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:02:59,241 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:02:59,351 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:03:01] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:03:05,803 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:03:05,913 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:03:07] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:03:12,490 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:03:12,604 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:03:14] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:03:23,819 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:03:23,932 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:03:25] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:03:34,877 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:03:34,993 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:03:36] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:03:45,709 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:03:45,821 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:03:47] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:03:56,846 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:03:56,960 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:03:58] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:04:07,779 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:04:07,893 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:04:10] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:04:17,569 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:04:17,682 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:04:19] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:04:27,192 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:04:27,304 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:04:29] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:04:36,789 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:04:36,904 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:04:38] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:04:46,264 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:04:46,381 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:04:48] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:04:55,970 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:04:56,090 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:04:58] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:05:09,222 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:05:09,337 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:05:11] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:05:22,080 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:05:22,197 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:05:24] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:05:34,928 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:05:35,042 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:05:36] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:05:47,661 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:05:47,772 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:05:49] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:06:01,016 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:01,128 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:06:03] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:06:06,492 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:06,607 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:06:08] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:06:11,440 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:11,566 - distributed.utils_perf - WARNING - full garbage collections took 76% CPU time recently (threshold: 10%)
# [08:06:13] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:06:16,378 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:16,495 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:06:18] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:06:21,337 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:21,453 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:06:23] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:06:26,258 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:26,375 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:06:28] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:06:35,865 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:35,980 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:06:37] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:06:44,964 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:45,078 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:06:47] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:06:54,155 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:06:54,270 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:06:56] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:07:03,399 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:07:03,515 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:07:05] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:07:12,402 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:07:12,519 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:07:14] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:07:22,776 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:07:22,893 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:07:24] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:07:32,483 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:07:32,597 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:07:34] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:07:42,211 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:07:42,327 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:07:44] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:07:51,971 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:07:52,087 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:07:53] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:08:01,604 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:08:01,720 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:08:04] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:08:09,692 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:08:09,808 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:08:11] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:08:17,402 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:08:17,513 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:08:19] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:08:24,873 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:08:24,989 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:08:26] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:08:32,402 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:08:32,518 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:08:34] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:08:39,867 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:08:39,981 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:08:42] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:08:48,087 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:08:48,204 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:08:50] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:08:55,862 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:08:55,977 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:08:57] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:09:03,469 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:09:03,582 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:09:05] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:09:11,165 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:09:11,278 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:09:13] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:09:18,960 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:09:19,076 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:09:21] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:09:26,680 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:09:26,798 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:09:28] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:09:33,916 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:09:34,034 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:09:35] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:09:41,140 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:09:41,253 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:09:43] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:09:48,285 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:09:48,403 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:09:50] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:09:55,491 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:09:55,606 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:09:57] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:10:03,832 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:10:03,947 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:10:05] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:10:11,872 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:10:11,987 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:10:13] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:10:19,823 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:10:19,941 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:10:21] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:10:27,743 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:10:27,861 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:10:29] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:10:35,694 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:10:35,814 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:10:38] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:10:43,346 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:10:43,462 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:10:45] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:10:50,642 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:10:50,763 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:10:52] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 08:10:57,872 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:10:57,990 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:10:59] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 08:11:04,918 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:11:05,035 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:11:06] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 08:11:12,103 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:11:12,220 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [08:11:14] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 08:11:19,841 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:11:19,960 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:11:21] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 08:11:27,162 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:11:27,284 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:11:29] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 08:11:34,387 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:11:34,507 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:11:36] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 08:11:41,539 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:11:41,658 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# [08:11:43] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 08:11:48,728 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# 2023-09-07 08:11:48,849 - distributed.utils_perf - WARNING - full garbage collections took 77% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# ...
# 2023-09-07 09:00:43,280 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:00:43,437 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:00:45] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 09:00:49,831 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:00:49,989 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:00:51] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 09:00:56,442 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:00:56,601 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:00:58] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 09:01:03,028 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:03,186 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:01:05] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 09:01:10,354 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:10,510 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:01:12] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 09:01:17,318 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:17,473 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:01:19] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 09:01:23,957 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:24,114 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:01:25] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 09:01:30,705 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:30,864 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:01:32] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 09:01:37,454 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:37,607 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:01:39] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 09:01:44,856 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:45,013 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:01:46] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 09:01:51,904 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:52,060 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:01:53] task [xgboost.dask-6]:tcp://127.0.0.1:34545 got new rank 0
# 2023-09-07 09:01:58,707 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:01:58,863 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:02:00] task [xgboost.dask-4]:tcp://127.0.0.1:44281 got new rank 0
# 2023-09-07 09:02:05,770 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:02:05,927 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:02:07] task [xgboost.dask-0]:tcp://127.0.0.1:43067 got new rank 0
# 2023-09-07 09:02:12,821 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:02:12,975 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# /tmp/ipykernel_3141099/3877596809.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_3141099/3877596809.py:12: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_3141099/3877596809.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_3141099/3877596809.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:02:15] task [xgboost.dask-3]:tcp://127.0.0.1:42235 got new rank 0
# 2023-09-07 09:02:20,444 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:02:20,603 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:02:22] task [xgboost.dask-2]:tcp://127.0.0.1:40123 got new rank 0
# 2023-09-07 09:02:27,814 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:02:27,972 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:02:29] task [xgboost.dask-7]:tcp://127.0.0.1:39891 got new rank 0
# 2023-09-07 09:02:34,954 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:02:35,107 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:02:37] task [xgboost.dask-1]:tcp://127.0.0.1:38477 got new rank 0
# 2023-09-07 09:02:42,269 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:02:42,428 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# [09:02:44] task [xgboost.dask-5]:tcp://127.0.0.1:35333 got new rank 0
# 2023-09-07 09:02:49,577 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# 2023-09-07 09:02:49,735 - distributed.utils_perf - WARNING - full garbage collections took 81% CPU time recently (threshold: 10%)
# CPU times: user 6min 34s, sys: 3min 12s, total: 9min 47s
# Wall time: 1h 4min 55s
#     number     value  params_alpha  params_colsample_bytree  \
# 0        0  0.260580      0.518387                 0.588129
# 1        1  0.272333      0.554771                 0.386440
# 2        2  0.273310      0.001337                 0.321878
# 3        3  0.213742      0.475032                 0.907356
# 4        4  0.250605      7.983068                 0.797204
# 5        5  0.279674      0.039072                 0.650555
# 6        6  0.270530      0.040732                 0.589670
# 7        7  0.231640      8.520712                 0.554478
# 8        8  0.230918      0.001495                 0.590447
# 9        9  0.278363      0.040354                 0.997855
# 10      10  0.236115      0.009281                 0.727463
# 11      11  0.278519      0.031540                 0.998693
# 12      12  0.270203      0.015902                 0.834853
# 13      13  0.270034      0.115583                 0.995798
# 14      14  0.269591      0.006036                 0.724604
# 15      15  0.281162      0.100424                 0.886439
# 16      16  0.279403      0.122200                 0.683843
# 17      17  0.265126      0.003847                 0.874794
# 18      18  0.283030      0.189473                 0.786495
# 19      19  0.282867      0.236346                 0.787282
#
#    params_eval_metric  params_lambda  params_learning_rate  params_max_depth  \
# 0             logloss       0.803620              0.001024                19
# 1             logloss       0.515043              0.004684                19
# 2             logloss       0.224638              0.035482                25
# 3             logloss       0.025882              0.019162                21
# 4             logloss       1.452732              0.037789                 8
# 5             logloss       3.588531              0.005713                16
# 6             logloss       0.035789              0.001149                24
# 7             logloss       2.060507              0.039615                23
# 8             logloss       0.322005              0.014818                18
# 9             logloss       0.380830              0.006666                15
# 10            logloss       6.826429              0.080534                 8
# 11            logloss       0.001268              0.005779                14
# 12            logloss       0.001515              0.003594                13
# 13            logloss       0.001123              0.002889                12
# 14            logloss       0.007130              0.008406                 4
# 15            logloss       9.722317              0.010164                16
# 16            logloss       8.528440              0.010894                16
# 17            logloss       3.673695              0.002611                10
# 18            logloss       9.743074              0.010903                17
# 19            logloss       9.382729              0.011743                21
#
#     params_min_child_weight params_objective  params_subsample  \
# 0                        73  binary:logistic          0.734509
# 1                       226  binary:logistic          0.740431
# 2                       235  binary:logistic          0.647692
# 3                         5  binary:logistic          0.939027
# 4                        12  binary:logistic          0.532211
# 5                        70  binary:logistic          0.882057
# 6                       155  binary:logistic          0.813833
# 7                        10  binary:logistic          0.537622
# 8                         7  binary:logistic          0.822372
# 9                        32  binary:logistic          0.484852
# 10                      114  binary:logistic          0.988347
# 11                       83  binary:logistic          0.447190
# 12                      144  binary:logistic          0.411015
# 13                       85  binary:logistic          0.658448
# 14                      293  binary:logistic          0.404685
# 15                       65  binary:logistic          0.593792
# 16                       53  binary:logistic          0.594768
# 17                      126  binary:logistic          0.894595
# 18                      184  binary:logistic          0.806433
# 19                      185  binary:logistic          0.605493
#
#    params_tree_method     state
# 0            gpu_hist  COMPLETE
# 1            gpu_hist  COMPLETE
# 2            gpu_hist  COMPLETE
# 3            gpu_hist  COMPLETE
# 4            gpu_hist  COMPLETE
# 5            gpu_hist  COMPLETE
# 6            gpu_hist  COMPLETE
# 7            gpu_hist  COMPLETE
# 8            gpu_hist  COMPLETE
# 9            gpu_hist  COMPLETE
# 10           gpu_hist  COMPLETE
# 11           gpu_hist  COMPLETE
# 12           gpu_hist  COMPLETE
# 13           gpu_hist  COMPLETE
# 14           gpu_hist  COMPLETE
# 15           gpu_hist  COMPLETE
# 16           gpu_hist  COMPLETE
# 17           gpu_hist  COMPLETE
# 18           gpu_hist  COMPLETE
# 19           gpu_hist  COMPLETE

# %%
df.value.max()
# Out:
# 0.2834224878819652

# %%
study.best_trial.params
# Out:
# {'objective': 'binary:logistic',
#  'tree_method': 'gpu_hist',
#  'lambda': 4.645511068481069,
#  'alpha': 0.6541465638507157,
#  'colsample_bytree': 0.917582587241956,
#  'subsample': 0.6600696894938839,
#  'learning_rate': 0.013000704738565036,
#  'max_depth': 7,
#  'min_child_weight': 194,
#  'eval_metric': 'logloss'}
