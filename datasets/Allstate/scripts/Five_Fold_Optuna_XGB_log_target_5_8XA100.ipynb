# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2023-08-24T09:29:17.872814-07:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.14.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 5.15.0-1029-nvidia
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 256
# Architecture: 64bit

# %%
from dask.distributed import Client
from dask_cuda import LocalCUDACluster
from dask import dataframe as dd
from dask.delayed import delayed
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import optuna
import gc
import logging

# %%
# %watermark --iversions
# Out:
# logging: 0.5.1.2
# optuna : 3.3.0
# pandas : 1.5.3
# dask   : 2023.3.2
# xgboost: 1.7.6
# numpy  : 1.24.4

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-80GB (UUID: GPU-cf1d9297-d9c3-6b2a-8afa-e63e4b5abb2d)
# GPU 1: NVIDIA A100-SXM4-80GB (UUID: GPU-6d18acdc-2136-40ac-5eeb-724e81476385)
# GPU 2: NVIDIA A100-SXM4-80GB (UUID: GPU-a87c7d38-52d2-befc-e2de-3cf90f75d6eb)
# GPU 3: NVIDIA A100-SXM4-80GB (UUID: GPU-8e290e7b-dec5-1828-2ec2-a6930ecd4b5b)
# GPU 4: NVIDIA A100-SXM4-80GB (UUID: GPU-36f4174f-2697-e22e-3ae5-0d30e814c4f1)
# GPU 5: NVIDIA A100-SXM4-80GB (UUID: GPU-d0929bb4-8c8c-8418-70d2-f658013f4b33)
# GPU 6: NVIDIA A100-SXM4-80GB (UUID: GPU-78f54132-3566-5a8c-b51b-fb3cc695d648)
# GPU 7: NVIDIA A100-SXM4-80GB (UUID: GPU-61b9f63d-cb20-77e8-8b22-40f40fbb8715)

# %%
cluster = LocalCUDACluster(n_workers=8)
client = Client(cluster)
# Out:
# 2023-08-24 09:31:34,495 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-08-24 09:31:34,495 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-08-24 09:31:34,503 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-08-24 09:31:34,503 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-08-24 09:31:34,508 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-08-24 09:31:34,508 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-08-24 09:31:34,508 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-08-24 09:31:34,508 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-08-24 09:31:34,512 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-08-24 09:31:34,512 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-08-24 09:31:34,518 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-08-24 09:31:34,518 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-08-24 09:31:34,523 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-08-24 09:31:34,523 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-08-24 09:31:34,523 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-08-24 09:31:34,523 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize

# %%
# !nvidia-smi
# Out:
# Thu Aug 24 09:31:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   35C    P0    71W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   33C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-SXM...  On   | 00000000:47:00.0 Off |                    0 |
# | N/A   33C    P0    66W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-SXM...  On   | 00000000:4E:00.0 Off |                    0 |
# | N/A   33C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100-SXM...  On   | 00000000:87:00.0 Off |                    0 |
# | N/A   38C    P0    66W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100-SXM...  On   | 00000000:90:00.0 Off |                    0 |
# | N/A   36C    P0    70W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100-SXM...  On   | 00000000:B7:00.0 Off |                    0 |
# | N/A   35C    P0    67W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100-SXM...  On   | 00000000:BD:00.0 Off |                    0 |
# | N/A   36C    P0    68W / 400W |    417MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A   1726023      C   /usr/bin/python3                  414MiB |
# |    1   N/A  N/A   1726025      C   /usr/bin/python3                  414MiB |
# |    2   N/A  N/A   1726029      C   /usr/bin/python3                  414MiB |
# |    3   N/A  N/A   1726031      C   /usr/bin/python3                  414MiB |
# |    4   N/A  N/A   1726035      C   /usr/bin/python3                  414MiB |
# |    5   N/A  N/A   1726037      C   /usr/bin/python3                  414MiB |
# |    6   N/A  N/A   1726041      C   /usr/bin/python3                  414MiB |
# |    7   N/A  N/A   1726043      C   /usr/bin/python3                  414MiB |
# +-----------------------------------------------------------------------------+

# %%
train_folds = []
val_folds = []
train_ys = []
val_ys = []

for i in range(5):
    print(f'Loading fold {i}')
    train_fold_d = delayed(pd.read_csv)(f'../input/xgtrain_fold_{i}_l.csv.gz')
    train_fold = dd.from_delayed(train_fold_d)
    
    val_fold_d = delayed(pd.read_csv)(f'../input/xgval_fold_{i}_l.csv.gz')
    val_fold = dd.from_delayed(val_fold_d)
    
    
    train_y = train_fold['target']
    train_fold = train_fold[train_fold.columns.difference(['target'])]
    
    val_y = val_fold['target']
    val_fold = val_fold[val_fold.columns.difference(['target'])]
    
    train_folds.append(train_fold)
    val_folds.append(val_fold)
    
    train_ys.append(train_y)
    val_ys.append(val_y)
# Out:
# Loading fold 0
# Loading fold 1
# Loading fold 2
# Loading fold 3
# Loading fold 4

# %%
train = pd.read_csv('../input/train.csv.zip')

shift = 200

target0 = train['loss'].values
target = np.log(target0+shift)

# %%
train_oof = np.zeros((target.shape[0],))

num_round = 1000

def objective(trial):
        
    params = {
        'objective': 'reg:squarederror', 
        'base_score':7.76,
        'tree_method':'gpu_hist',  # 'gpu_hist','hist'
        'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
        'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
        'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
        'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
        'max_depth': trial.suggest_int('max_depth', 3, 25),
        'min_child_weight': trial.suggest_int('min_child_weight', 1,300),
        'eval_metric': trial.suggest_categorical('eval_metric',['rmse']),

    }

    kf = KFold(5, shuffle=True, random_state=137)

    for i, (train_index, val_index) in enumerate(kf.split(train,target)):
        dtrain = xgb.dask.DaskDMatrix(client, train_folds[i].values, train_ys[i], enable_categorical=True)
        dval = xgb.dask.DaskDMatrix(client, val_folds[i].values, val_ys[i], enable_categorical=True)
        
        output = xgb.dask.train(client, params, dtrain, num_round)
        booster = output['booster']  # booster is the trained model
        booster.set_param({'predictor': 'gpu_predictor'})
        predictions = xgb.dask.predict(client, booster, dval)
        predictions = predictions.compute()
        train_oof[val_index] = np.exp(predictions) - shift
        del dtrain, dval, output
        gc.collect()
        gc.collect()

    mae = mean_absolute_error(target0, train_oof)
    
    return mae

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Setup the root logger.
logger.addHandler(logging.FileHandler("optuna_xgb_output_l_5.log", mode="w"))

optuna.logging.enable_propagation()  # Propagate logs to the root logger.
optuna.logging.disable_default_handler()  # Stop showing logs in sys.stderr.

study = optuna.create_study(study_name="five_fold_optuna_xgb_l_5", direction='minimize')

# %%
# %%time
logger.info("Start optimization.")
study.optimize(objective, n_trials=3)
# Out:
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:35:00] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# [09:35:14] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# [09:35:26] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# [09:35:38] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# [09:35:49] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:36:01] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# [09:36:32] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# [09:37:02] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# [09:37:32] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# [09:38:02] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:38:32] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# [09:38:36] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# [09:38:40] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# [09:38:44] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# [09:38:48] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:38:50,785 - distributed.utils_perf - WARNING - full garbage collections took 57% CPU time recently (threshold: 10%)
# CPU times: user 29.9 s, sys: 15.2 s, total: 45.1 s
# Wall time: 3min 51s

# %%
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.head()
# Out:
#    number        value  params_alpha  params_colsample_bytree  \
# 0       0  1190.001472      0.002029                 0.645026
# 1       1  1214.553923      0.012982                 0.508748
# 2       2  1223.155930      7.095743                 0.464230
#
#   params_eval_metric  params_gamma  params_lambda  params_learning_rate  \
# 0               rmse      0.188941       0.044873              0.003243
# 1               rmse      0.047713       0.661674              0.072797
# 2               rmse      0.026537       2.551509              0.005636
#
#    params_max_depth  params_min_child_weight  params_subsample     state
# 0                12                      213          0.690521  COMPLETE
# 1                20                       47          0.567355  COMPLETE
# 2                 4                      189          0.510813  COMPLETE

# %%
# %%time
study.optimize(objective, n_trials=5)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_l_5.csv', index=False)
df
# Out:
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:41:38] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:41:48,127 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:41:48,235 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:41:49] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:41:58,589 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:41:58,695 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:41:59] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:42:09,144 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:09,252 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:42:10] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:42:19,820 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:19,928 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:42:21] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:42:30,200 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:30,307 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:42:31] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:42:34,040 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:34,147 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:42:35] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:42:37,830 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:37,936 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:42:39] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:42:41,677 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:41,786 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:42:42] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:42:45,489 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:45,599 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:42:46] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:42:49,269 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:49,378 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:42:50] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:42:57,800 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:42:57,910 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:42:59] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:43:06,226 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:06,336 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:43:07] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:43:14,585 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:14,694 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:43:15] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:43:22,924 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:23,030 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:43:24] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:43:31,123 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:31,230 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:43:32] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:43:36,014 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:36,121 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:43:37] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:43:40,904 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:41,015 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:43:42] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:43:45,717 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:45,824 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:43:47] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:43:50,672 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:50,782 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:43:52] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:43:55,708 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:43:55,821 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:43:57] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:44:07,987 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:44:08,094 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:44:09] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:44:20,047 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:44:20,155 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:44:21] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:44:32,080 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:44:32,187 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:44:33] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:44:44,093 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:44:44,200 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:44:45] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:44:56,287 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:44:56,398 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# CPU times: user 17.2 s, sys: 11.8 s, total: 29 s
# Wall time: 3min 18s
#    number        value  params_alpha  params_colsample_bytree  \
# 0       0  1190.001472      0.002029                 0.645026
# 1       1  1214.553923      0.012982                 0.508748
# 2       2  1223.155930      7.095743                 0.464230
# 3       3  1175.212443      0.001856                 0.516115
# 4       4  1167.556218      0.002650                 0.836034
# 5       5  1139.772621      0.003600                 0.860221
# 6       6  1172.661932      0.057375                 0.983912
# 7       7  1148.443350      0.001981                 0.802602
#
#   params_eval_metric  params_gamma  params_lambda  params_learning_rate  \
# 0               rmse      0.188941       0.044873              0.003243
# 1               rmse      0.047713       0.661674              0.072797
# 2               rmse      0.026537       2.551509              0.005636
# 3               rmse      0.089468       6.777876              0.004042
# 4               rmse      0.027081       0.007916              0.014568
# 5               rmse      0.002255       0.002139              0.023810
# 6               rmse      0.077003       0.013820              0.007072
# 7               rmse      0.310054       0.346462              0.042305
#
#    params_max_depth  params_min_child_weight  params_subsample     state
# 0                12                      213          0.690521  COMPLETE
# 1                20                       47          0.567355  COMPLETE
# 2                 4                      189          0.510813  COMPLETE
# 3                11                      234          0.903623  COMPLETE
# 4                 4                        5          0.649490  COMPLETE
# 5                12                      259          0.684108  COMPLETE
# 6                 6                      285          0.768610  COMPLETE
# 7                23                      130          0.771725  COMPLETE

# %%
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.head(8)
# Out:
#    number        value  params_alpha  params_colsample_bytree  \
# 0       0  1190.001472      0.002029                 0.645026
# 1       1  1214.553923      0.012982                 0.508748
# 2       2  1223.155930      7.095743                 0.464230
# 3       3  1175.212443      0.001856                 0.516115
# 4       4  1167.556218      0.002650                 0.836034
# 5       5  1139.772621      0.003600                 0.860221
# 6       6  1172.661932      0.057375                 0.983912
# 7       7  1148.443350      0.001981                 0.802602
#
#   params_eval_metric  params_gamma  params_lambda  params_learning_rate  \
# 0               rmse      0.188941       0.044873              0.003243
# 1               rmse      0.047713       0.661674              0.072797
# 2               rmse      0.026537       2.551509              0.005636
# 3               rmse      0.089468       6.777876              0.004042
# 4               rmse      0.027081       0.007916              0.014568
# 5               rmse      0.002255       0.002139              0.023810
# 6               rmse      0.077003       0.013820              0.007072
# 7               rmse      0.310054       0.346462              0.042305
#
#    params_max_depth  params_min_child_weight  params_subsample     state
# 0                12                      213          0.690521  COMPLETE
# 1                20                       47          0.567355  COMPLETE
# 2                 4                      189          0.510813  COMPLETE
# 3                11                      234          0.903623  COMPLETE
# 4                 4                        5          0.649490  COMPLETE
# 5                12                      259          0.684108  COMPLETE
# 6                 6                      285          0.768610  COMPLETE
# 7                23                      130          0.771725  COMPLETE

# %%
# %%time
study.optimize(objective, n_trials=100)
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
df.to_csv('optuna_xgb_output_l_5.csv', index=False)
df.head()
# Out:
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:48:24] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:48:26,605 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:48:26,714 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:48:27] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:48:30,522 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:48:30,635 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:48:31] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:48:34,421 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:48:34,535 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:48:35] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:48:38,241 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:48:38,352 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:48:39] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:48:42,104 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:48:42,215 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:48:43] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:48:54,375 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:48:54,484 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:48:55] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:49:06,777 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:49:06,886 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:49:08] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:49:19,238 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:49:19,351 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:49:20] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:49:31,712 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:49:31,824 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# [09:49:33] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:49:44,197 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# 2023-08-24 09:49:44,312 - distributed.utils_perf - WARNING - full garbage collections took 88% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:49:45] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:49:58,771 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:49:58,884 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:50:00] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:50:13,215 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:50:13,325 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:50:14] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:50:27,305 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:50:27,415 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:50:28] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:50:41,401 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:50:41,512 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:50:42] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:50:56,046 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:50:56,157 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:50:57] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:51:01,799 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:01,915 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:03] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:51:07,481 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:07,595 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:08] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:51:13,174 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:13,289 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:14] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:51:18,914 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:19,029 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:20] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:51:24,603 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:24,716 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:51:25] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:51:28,789 - distributed.utils_perf - WARNING - full garbage collections took 86% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:28,902 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:30] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:51:32,908 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:33,020 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:34] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:51:37,016 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:37,129 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:38] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:51:41,102 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:41,220 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:42] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:51:45,210 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:45,326 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:51:46] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:51:51,763 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:51,880 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:53] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:51:58,306 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:51:58,423 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:51:59] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:52:04,807 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:04,920 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:52:06] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:52:11,295 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:11,407 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:52:12] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:52:17,761 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:17,874 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:52:19] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:52:23,842 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:23,959 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:52:25] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:52:29,933 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:30,050 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:52:31] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:52:35,998 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:36,114 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:52:37] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:52:42,074 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:42,189 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:52:43] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:52:48,179 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:48,298 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:52:49] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:52:54,354 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:52:54,469 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:52:55] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:53:00,528 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:53:00,643 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:53:01] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:53:06,634 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:53:06,748 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:53:07] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:53:12,856 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:53:12,972 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:53:14] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:53:19,752 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:53:19,870 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:53:21] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:53:32,559 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:53:32,674 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:53:33] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:53:45,452 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:53:45,570 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:53:46] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:53:58,487 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:53:58,601 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:53:59] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:54:11,251 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:54:11,367 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:54:12] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:54:24,108 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:54:24,224 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:54:25] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:54:38,076 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:54:38,193 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:54:39] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:54:52,102 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:54:52,220 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:54:53] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:55:06,096 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:55:06,216 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:55:07] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:55:20,260 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:55:20,378 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:55:21] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:55:34,226 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:55:34,350 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:55:35] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:55:47,133 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:55:47,256 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:55:48] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:56:00,062 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:56:00,181 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:56:01] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:56:12,907 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:56:13,023 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:56:14] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:56:26,044 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:56:26,162 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:56:27] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:56:38,873 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:56:38,992 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:56:40] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:56:48,864 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:56:48,987 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:56:50] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:56:59,003 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:56:59,122 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:57:00] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:57:08,892 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:57:09,016 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:57:10] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:57:19,027 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:57:19,149 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:57:20] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:57:29,166 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:57:29,284 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:57:30] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 09:57:44,057 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:57:44,174 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:57:45] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 09:57:58,776 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:57:58,893 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:58:00] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 09:58:13,361 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:58:13,481 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:58:14] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 09:58:28,314 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:58:28,435 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:58:29] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 09:58:42,825 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:58:42,943 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [09:58:44] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 09:58:58,142 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:58:58,264 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:58:59] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 09:59:13,276 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:59:13,399 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:59:14] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 09:59:28,166 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# 2023-08-24 09:59:28,285 - distributed.utils_perf - WARNING - full garbage collections took 87% CPU time recently (threshold: 10%)
# [09:59:29] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# ...
# [11:12:33] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 11:12:45,244 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:12:45,403 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:12:46] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 11:12:58,117 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:12:58,277 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [11:12:59] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 11:13:11,615 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:13:11,814 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:13:13] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 11:13:25,314 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:13:25,481 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:13:26] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 11:13:38,759 - distributed.utils_perf - WARNING - full garbage collections took 90% CPU time recently (threshold: 10%)
# 2023-08-24 11:13:38,921 - distributed.utils_perf - WARNING - full garbage collections took 90% CPU time recently (threshold: 10%)
# [11:13:40] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 11:13:52,033 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:13:52,191 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:13:53] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 11:14:05,379 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:14:05,537 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [11:14:06] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 11:14:19,460 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:14:19,629 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:14:20] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 11:14:34,243 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:14:34,402 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:14:35] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 11:14:48,608 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:14:48,768 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:14:49] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 11:15:02,708 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:15:02,867 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:15:04] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 11:15:16,985 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:15:17,149 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [11:15:18] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 11:15:32,166 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:15:32,326 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:15:33] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 11:15:47,103 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:15:47,262 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:15:48] task [xgboost.dask-6]:tcp://127.0.0.1:33861 got new rank 0
# 2023-08-24 11:16:02,019 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:16:02,177 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:16:03] task [xgboost.dask-5]:tcp://127.0.0.1:44929 got new rank 0
# 2023-08-24 11:16:16,700 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:16:16,858 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:16:18] task [xgboost.dask-0]:tcp://127.0.0.1:42295 got new rank 0
# 2023-08-24 11:16:32,194 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:16:32,356 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# /tmp/ipykernel_1708879/3816880036.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma',1e-3,10.0),
# /tmp/ipykernel_1708879/3816880036.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
# /tmp/ipykernel_1708879/3816880036.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
# /tmp/ipykernel_1708879/3816880036.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
# [11:16:33] task [xgboost.dask-2]:tcp://127.0.0.1:41353 got new rank 0
# 2023-08-24 11:16:48,642 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:16:48,803 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:16:50] task [xgboost.dask-4]:tcp://127.0.0.1:37121 got new rank 0
# 2023-08-24 11:17:05,154 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:17:05,311 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:17:06] task [xgboost.dask-3]:tcp://127.0.0.1:37027 got new rank 0
# 2023-08-24 11:17:21,827 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:17:21,988 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:17:23] task [xgboost.dask-1]:tcp://127.0.0.1:36975 got new rank 0
# 2023-08-24 11:17:38,143 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:17:38,300 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# [11:17:39] task [xgboost.dask-7]:tcp://127.0.0.1:35899 got new rank 0
# 2023-08-24 11:17:54,476 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# 2023-08-24 11:17:54,632 - distributed.utils_perf - WARNING - full garbage collections took 89% CPU time recently (threshold: 10%)
# CPU times: user 7min 45s, sys: 4min 43s, total: 12min 29s
# Wall time: 1h 29min 31s
#    number        value  params_alpha  params_colsample_bytree  \
# 0       0  1190.001472      0.002029                 0.645026
# 1       1  1214.553923      0.012982                 0.508748
# 2       2  1223.155930      7.095743                 0.464230
# 3       3  1175.212443      0.001856                 0.516115
# 4       4  1167.556218      0.002650                 0.836034
#
#   params_eval_metric  params_gamma  params_lambda  params_learning_rate  \
# 0               rmse      0.188941       0.044873              0.003243
# 1               rmse      0.047713       0.661674              0.072797
# 2               rmse      0.026537       2.551509              0.005636
# 3               rmse      0.089468       6.777876              0.004042
# 4               rmse      0.027081       0.007916              0.014568
#
#    params_max_depth  params_min_child_weight  params_subsample     state
# 0                12                      213          0.690521  COMPLETE
# 1                20                       47          0.567355  COMPLETE
# 2                 4                      189          0.510813  COMPLETE
# 3                11                      234          0.903623  COMPLETE
# 4                 4                        5          0.649490  COMPLETE

# %%
df
# Out:
#      number        value  params_alpha  params_colsample_bytree  \
# 0         0  1190.001472      0.002029                 0.645026
# 1         1  1214.553923      0.012982                 0.508748
# 2         2  1223.155930      7.095743                 0.464230
# 3         3  1175.212443      0.001856                 0.516115
# 4         4  1167.556218      0.002650                 0.836034
# ..      ...          ...           ...                      ...
# 103     103  1135.869617      0.005817                 0.338481
# 104     104  1135.593256      0.005858                 0.335532
# 105     105  1135.450475      0.006291                 0.333303
# 106     106  1135.652158      0.006019                 0.334024
# 107     107  1135.935686      0.008415                 0.332817
#
#     params_eval_metric  params_gamma  params_lambda  params_learning_rate  \
# 0                 rmse      0.188941       0.044873              0.003243
# 1                 rmse      0.047713       0.661674              0.072797
# 2                 rmse      0.026537       2.551509              0.005636
# 3                 rmse      0.089468       6.777876              0.004042
# 4                 rmse      0.027081       0.007916              0.014568
# ..                 ...           ...            ...                   ...
# 103               rmse      0.003247       0.001389              0.016276
# 104               rmse      0.003024       0.001970              0.015954
# 105               rmse      0.003143       0.001345              0.016706
# 106               rmse      0.003323       0.001533              0.016839
# 107               rmse      0.002154       0.001339              0.014068
#
#      params_max_depth  params_min_child_weight  params_subsample     state
# 0                  12                      213          0.690521  COMPLETE
# 1                  20                       47          0.567355  COMPLETE
# 2                   4                      189          0.510813  COMPLETE
# 3                  11                      234          0.903623  COMPLETE
# 4                   4                        5          0.649490  COMPLETE
# ..                ...                      ...               ...       ...
# 103                15                      206          0.999222  COMPLETE
# 104                16                      212          0.997828  COMPLETE
# 105                16                      185          0.997285  COMPLETE
# 106                17                      186          0.971556  COMPLETE
# 107                18                      184          0.969619  COMPLETE
#
# [108 rows x 12 columns]

# %%
df.head(20)
# Out:
#     number        value  params_alpha  params_colsample_bytree  \
# 0        0  1190.001472      0.002029                 0.645026
# 1        1  1214.553923      0.012982                 0.508748
# 2        2  1223.155930      7.095743                 0.464230
# 3        3  1175.212443      0.001856                 0.516115
# 4        4  1167.556218      0.002650                 0.836034
# 5        5  1139.772621      0.003600                 0.860221
# 6        6  1172.661932      0.057375                 0.983912
# 7        7  1148.443350      0.001981                 0.802602
# 8        8  1198.188980      0.001084                 0.426592
# 9        9  1149.864368      0.441480                 0.869913
# 10      10  1401.675766      0.016419                 0.323041
# 11      11  1144.723427      0.009874                 0.760185
# 12      12  1167.227770      0.010692                 0.706945
# 13      13  1141.730882      0.007989                 0.984289
# 14      14  1148.470033      0.068244                 0.986756
# 15      15  1156.790971      0.005557                 0.901865
# 16      16  1138.387350      0.036286                 0.921959
# 17      17  1139.808881      0.036317                 0.909633
# 18      18  1150.088717      0.182329                 0.755088
# 19      19  1137.171168      0.028160                 0.662811
#
#    params_eval_metric  params_gamma  params_lambda  params_learning_rate  \
# 0                rmse      0.188941       0.044873              0.003243
# 1                rmse      0.047713       0.661674              0.072797
# 2                rmse      0.026537       2.551509              0.005636
# 3                rmse      0.089468       6.777876              0.004042
# 4                rmse      0.027081       0.007916              0.014568
# 5                rmse      0.002255       0.002139              0.023810
# 6                rmse      0.077003       0.013820              0.007072
# 7                rmse      0.310054       0.346462              0.042305
# 8                rmse      1.048344       0.001766              0.007574
# 9                rmse      0.004837       0.007952              0.036756
# 10               rmse      0.001085       0.001508              0.001231
# 11               rmse      1.655235       0.218974              0.027733
# 12               rmse      7.708658       0.110162              0.021574
# 13               rmse      0.007232       0.045832              0.018152
# 14               rmse      0.005939       0.055439              0.011458
# 15               rmse      0.001336       0.024497              0.099292
# 16               rmse      0.008268       0.003057              0.015887
# 17               rmse      0.003303       0.003586              0.012927
# 18               rmse      0.014657       0.001178              0.045432
# 19               rmse      0.002339       0.003778              0.022680
#
#     params_max_depth  params_min_child_weight  params_subsample     state
# 0                 12                      213          0.690521  COMPLETE
# 1                 20                       47          0.567355  COMPLETE
# 2                  4                      189          0.510813  COMPLETE
# 3                 11                      234          0.903623  COMPLETE
# 4                  4                        5          0.649490  COMPLETE
# 5                 12                      259          0.684108  COMPLETE
# 6                  6                      285          0.768610  COMPLETE
# 7                 23                      130          0.771725  COMPLETE
# 8                  4                      241          0.783647  COMPLETE
# 9                 18                      227          0.629913  COMPLETE
# 10                15                      129          0.416717  COMPLETE
# 11                22                      105          0.844024  COMPLETE
# 12                25                       60          0.939503  COMPLETE
# 13                 9                      300          0.868126  COMPLETE
# 14                 8                      298          0.869226  COMPLETE
# 15                 9                      268          0.718055  COMPLETE
# 16                15                      180          0.924112  COMPLETE
# 17                15                      175          0.990565  COMPLETE
# 18                17                      167          0.983591  COMPLETE
# 19                13                      197          0.816831  COMPLETE

# %%
df.tail(20)
# Out:
#      number        value  params_alpha  params_colsample_bytree  \
# 88       88  1135.905665      0.002532                 0.348138
# 89       89  1136.287056      0.002667                 0.349966
# 90       90  1136.588817      0.004426                 0.343979
# 91       91  1135.867863      0.002530                 0.335840
# 92       92  1135.790152      0.002582                 0.332980
# 93       93  1135.603978      0.003044                 0.333913
# 94       94  1135.808697      0.003065                 0.337994
# 95       95  1135.643982      0.006155                 0.337812
# 96       96  1136.818159      0.005935                 0.329883
# 97       97  1135.938297      0.004590                 0.314994
# 98       98  1135.408684      0.004289                 0.335150
# 99       99  1135.816526      0.008702                 0.314597
# 100     100  1136.118764      0.008250                 0.312816
# 101     101  1135.437495      0.004597                 0.337214
# 102     102  1136.239377      0.004596                 0.327438
# 103     103  1135.869617      0.005817                 0.338481
# 104     104  1135.593256      0.005858                 0.335532
# 105     105  1135.450475      0.006291                 0.333303
# 106     106  1135.652158      0.006019                 0.334024
# 107     107  1135.935686      0.008415                 0.332817
#
#     params_eval_metric  params_gamma  params_lambda  params_learning_rate  \
# 88                rmse      0.005808       0.001020              0.021711
# 89                rmse      0.006560       0.001145              0.017413
# 90                rmse      0.006071       0.001241              0.015965
# 91                rmse      0.003959       0.001019              0.018834
# 92                rmse      0.003714       0.001577              0.016956
# 93                rmse      0.003634       0.001176              0.017612
# 94                rmse      0.003622       0.001471              0.017698
# 95                rmse      0.004369       0.001343              0.021285
# 96                rmse      0.003633       0.001517              0.013661
# 97                rmse      0.004798       0.001886              0.020570
# 98                rmse      0.004779       0.001571              0.021589
# 99                rmse      0.004897       0.001493              0.020000
# 100               rmse      0.004396       0.001551              0.019746
# 101               rmse      0.002792       0.001889              0.021149
# 102               rmse      0.002548       0.001812              0.021328
# 103               rmse      0.003247       0.001389              0.016276
# 104               rmse      0.003024       0.001970              0.015954
# 105               rmse      0.003143       0.001345              0.016706
# 106               rmse      0.003323       0.001533              0.016839
# 107               rmse      0.002154       0.001339              0.014068
#
#      params_max_depth  params_min_child_weight  params_subsample     state
# 88                 14                      256          0.999959  COMPLETE
# 89                 14                      256          0.977861  COMPLETE
# 90                 16                      255          0.939597  COMPLETE
# 91                 14                      268          0.999887  COMPLETE
# 92                 14                      248          0.981259  COMPLETE
# 93                 15                      235          0.977843  COMPLETE
# 94                 14                      237          0.952538  COMPLETE
# 95                 15                      232          0.998880  COMPLETE
# 96                 15                      235          0.952704  COMPLETE
# 97                 15                      228          0.943804  COMPLETE
# 98                 15                      216          0.999967  COMPLETE
# 99                 15                      215          0.941773  COMPLETE
# 100                16                      216          0.933298  COMPLETE
# 101                15                      230          0.998607  COMPLETE
# 102                15                      227          0.946412  COMPLETE
# 103                15                      206          0.999222  COMPLETE
# 104                16                      212          0.997828  COMPLETE
# 105                16                      185          0.997285  COMPLETE
# 106                17                      186          0.971556  COMPLETE
# 107                18                      184          0.969619  COMPLETE

# %%
df.value.min()
# Out:
# 1135.4086836779738
