# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2026-06-13T09:02:25.486067-04:00
#
# Python implementation: CPython
# Python version       : 3.14.2
# IPython version      : 9.11.0
#
# Compiler    : Clang 17.0.0 (clang-1700.4.4.1)
# OS          : Darwin
# Release     : 24.5.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 20
# Architecture: 64bit

# %%
import keras_tuner
from tensorflow import keras
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import keras_tuner as kt
from tensorflow.keras import layers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import keras_tuner
#       2 from tensorflow import keras
#       3 import pandas as pd
#
# File /opt/homebrew/lib/python3.14/site-packages/keras_tuner/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras_tuner import applications as applications
#       9 from keras_tuner import engine as engine
#      10 from keras_tuner import errors as errors
#
# File /opt/homebrew/lib/python3.14/site-packages/keras_tuner/applications/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras_tuner.src.applications.augment import HyperImageAugment as HyperImageAugment
#       9 from keras_tuner.src.applications.efficientnet import HyperEfficientNet as HyperEfficientNet
#      10 from keras_tuner.src.applications.resnet import HyperResNet as HyperResNet
#
# File /opt/homebrew/lib/python3.14/site-packages/keras_tuner/src/__init__.py:16
#       1 # Copyright 2019 The KerasTuner Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 16 from keras_tuner.src import applications
#      17 from keras_tuner.src import oracles
#      18 from keras_tuner.src import tuners
#
# File /opt/homebrew/lib/python3.14/site-packages/keras_tuner/src/applications/__init__.py:16
#       1 # Copyright 2019 The KerasTuner Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 16 from keras_tuner.src.applications.augment import HyperImageAugment
#      17 from keras_tuner.src.applications.efficientnet import HyperEfficientNet
#      18 from keras_tuner.src.applications.resnet import HyperResNet
#
# File /opt/homebrew/lib/python3.14/site-packages/keras_tuner/src/applications/augment.py:17
#       1 # Copyright 2019 The KerasTuner Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      16 from keras_tuner.src.api_export import keras_tuner_export
# ---> 17 from keras_tuner.src.backend import keras
#      18 from keras_tuner.src.backend import ops
#      19 from keras_tuner.src.backend import random
#
# File /opt/homebrew/lib/python3.14/site-packages/keras_tuner/src/backend/__init__.py:26
#       1 # Copyright 2019 The KerasTuner Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 """
#      15 Keras backend module.
#      16
#    (...)     23 - `ops`: `keras.ops`, always tf backed if using `tf.keras`.
#      24 """
# ---> 26 from keras_tuner.src.backend import config
#      27 from keras_tuner.src.backend import io
#      28 from keras_tuner.src.backend import keras
#
# File /opt/homebrew/lib/python3.14/site-packages/keras_tuner/src/backend/config.py:15
#       1 # Copyright 2019 The KerasTuner Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 import keras
#      18 def _multi_backend():
#      19     version_fn = getattr(keras, "version", None)
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import _tf_keras as _tf_keras
#       8 from keras import activations as activations
#       9 from keras import applications as applications
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/_tf_keras/__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/_tf_keras/keras/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import activations as activations
#       8 from keras import applications as applications
#       9 from keras import callbacks as callbacks
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/activations/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize as deserialize
#       8 from keras.src.activations import get as get
#       9 from keras.src.activations import serialize as serialize
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/activations/__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import celu
#       4 from keras.src.activations.activations import elu
#       5 from keras.src.activations.activations import exponential
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/activations/activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/backend/__init__.py:1
# ----> 1 from keras.src.backend.config import backend
#       3 if backend() == "torch":
#       4     # When using the torch backend,
#       5     # torch needs to be imported first, otherwise it will segfault
#       6     # upon import.
#       7     import torch
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/backend/config.py:463
#     460     else:
#     461         _NNX_ENABLED = False
# --> 463 set_nnx_enabled(_NNX_ENABLED)
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/backend/config.py:249, in set_nnx_enabled(value)
#     247 def set_nnx_enabled(value):
#     248     global _NNX_ENABLED
# --> 249     from keras.src.backend.common import global_state
#     251     _NNX_ENABLED = bool(value)
#     252     if _NNX_ENABLED:
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/backend/common/__init__.py:2
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#       4 from keras.src.backend.common.variables import Variable as KerasVariable
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/backend/common/dtypes.py:5
#       3 from keras.src.api_export import keras_export
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#       8 INT_TYPES = (
#       9     "uint8",
#      10     "uint16",
#    (...)     16     "int64",
#      17 )
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/backend/common/variables.py:11
#       9 from keras.src.backend.common.stateless_scope import get_stateless_scope
#      10 from keras.src.backend.common.stateless_scope import in_stateless_scope
# ---> 11 from keras.src.utils.module_utils import tensorflow as tf
#      12 from keras.src.utils.naming import auto_name
#      15 class Variable:
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/utils/__init__.py:1
# ----> 1 from keras.src.utils.audio_dataset_utils import audio_dataset_from_directory
#       2 from keras.src.utils.dataset_utils import split_dataset
#       3 from keras.src.utils.file_utils import get_file
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/utils/audio_dataset_utils.py:4
#       1 import numpy as np
#       3 from keras.src.api_export import keras_export
# ----> 4 from keras.src.utils import dataset_utils
#       5 from keras.src.utils.module_utils import tensorflow as tf
#       6 from keras.src.utils.module_utils import tensorflow_io as tfio
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/utils/dataset_utils.py:10
#       7 import numpy as np
#       9 from keras.src import backend
# ---> 10 from keras.src import tree
#      11 from keras.src.api_export import keras_export
#      12 from keras.src.utils import file_utils
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/tree/__init__.py:1
# ----> 1 from keras.src.tree.tree_api import assert_same_paths
#       2 from keras.src.tree.tree_api import assert_same_structure
#       3 from keras.src.tree.tree_api import flatten
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/tree/tree_api.py:13
#      11     from keras.src.tree import torchtree_impl as tree_impl
#      12 elif optree.available:
# ---> 13     from keras.src.tree import optree_impl as tree_impl
#      14 elif dmtree.available:
#      15     from keras.src.tree import dmtree_impl as tree_impl
#
# File /opt/homebrew/lib/python3.14/site-packages/keras/src/tree/optree_impl.py:13
#      11 # Register backend-specific node classes
#      12 if backend() == "tensorflow":
# ---> 13     from tensorflow.python.trackable.data_structures import ListWrapper
#      14     from tensorflow.python.trackable.data_structures import _DictWrapper
#      16     try:
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# %watermark --iversions
# Out:
# tensorflow : 2.9.1
# numpy      : 1.22.4
# keras_tuner: 1.1.3
# pandas     : 1.4.3

# %%
def load_data(path):
    data = pd.read_csv(path)
    y = data["label"]
    x = data.drop(labels=["label"], axis=1).values.reshape(-1, 28, 28, 1)
    return x, y

x_train, y_train = load_data("../input/train.csv.gz")
x_test, y_test = load_data("../input/test.csv.gz")

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_test.shape
# Out:
# (10000, 28, 28, 1)

# %%
def augment_images(x, hp):
    use_rotation = hp.Boolean('use_rotation')
    if use_rotation:
        x = layers.experimental.preprocessing.RandomRotation(
            hp.Float('rotation_factor', min_value=0.05, max_value=0.2)
        )(x)
    use_zoom = hp.Boolean('use_zoom')
    if use_zoom:
        x = layers.experimental.preprocessing.RandomZoom(
            hp.Float('use_zoom', min_value=0.05, max_value=0.2)
        )(x)
    return x

def make_model(hp):
    inputs = keras.Input(shape=(28, 28, 1))
    x = layers.experimental.preprocessing.Rescaling(1. / 255)(inputs)
    x = layers.experimental.preprocessing.Resizing(64, 64)(x)
    x = augment_images(x, hp)
    
    num_block = hp.Int('num_block', min_value=2, max_value=5, step=1)
    num_filters = hp.Int('num_filters', min_value=32, max_value=128, step=32)
    for i in range(num_block):
        x = layers.Conv2D(
            num_filters,
            kernel_size=3,
            activation='relu',
            padding='same'
        )(x)
        x = layers.Conv2D(
            num_filters,
            kernel_size=3,
            activation='relu',
            padding='same'
        )(x)
        x = layers.MaxPooling2D(2)(x)
    
    reduction_type = hp.Choice('reduction_type', ['flatten', 'avg'])
    if reduction_type == 'flatten':
        x = layers.Flatten()(x)
    else:
        x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(
        units=hp.Int('num_dense_units', min_value=32, max_value=512, step=32),
        activation='relu'
    )(x)
    x = layers.Dropout(
        hp.Float('dense_dropout', min_value=0., max_value=0.7)
    )(x)
    outputs = layers.Dense(10)(x)
    model = keras.Model(inputs, outputs)
    
    learning_rate = hp.Float('learning_rate', min_value=3e-4, max_value=3e-3)
    optimizer = keras.optimizers.Adam(learning_rate=1e-3)
    model.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  optimizer=optimizer,
                  metrics=[keras.metrics.SparseCategoricalAccuracy(name='acc')])
    model.summary()
    return model

# %%
# %%time

tuner = kt.tuners.RandomSearch(
    make_model,
    objective='val_acc',
    max_trials=100,
    overwrite=True)

callbacks=[keras.callbacks.EarlyStopping(monitor='val_acc', mode='max', patience=3, baseline=0.9)]
tuner.search(x_train, y_train, validation_split=0.2, callbacks=callbacks, verbose=1, epochs=100)
# Out:
# Trial 100 Complete [00h 00m 40s]
# val_acc: 0.878166675567627
#
# Best val_acc So Far: 0.9319166541099548
# Total elapsed time: 02h 17m 46s
# INFO:tensorflow:Oracle triggered exit
# CPU times: user 2h 30min 58s, sys: 4min 43s, total: 2h 35min 41s
# Wall time: 2h 17min 47s

# %%
best_hp = tuner.get_best_hyperparameters()[0]
model = make_model(best_hp)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=50)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  rescaling_1 (Rescaling)     (None, 28, 28, 1)         0
#
#  resizing_1 (Resizing)       (None, 64, 64, 1)         0
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 96)        960
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 96)        83040
#
#  max_pooling2d_3 (MaxPooling  (None, 32, 32, 96)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 96)        83040
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 96)        83040
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 96)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 96)        83040
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 96)        83040
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 96)          83040
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 96)          83040
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  global_average_pooling2d_1   (None, 96)               0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 384)               37248
#
#  dropout_1 (Dropout)         (None, 384)               0
#
#  dense_3 (Dense)             (None, 10)                3850
#
# =================================================================
# Total params: 623,338
# Trainable params: 623,338
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.5756 - acc: 0.7843 - val_loss: 0.3358 - val_acc: 0.8746
# Epoch 2/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.3139 - acc: 0.8851 - val_loss: 0.3320 - val_acc: 0.8782
# Epoch 3/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.2608 - acc: 0.9047 - val_loss: 0.2546 - val_acc: 0.9075
# Epoch 4/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.2295 - acc: 0.9153 - val_loss: 0.2284 - val_acc: 0.9183
# Epoch 5/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.2040 - acc: 0.9251 - val_loss: 0.2336 - val_acc: 0.9179
# Epoch 6/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.1826 - acc: 0.9330 - val_loss: 0.2401 - val_acc: 0.9178
# Epoch 7/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.1617 - acc: 0.9400 - val_loss: 0.2220 - val_acc: 0.9218
# Epoch 8/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.1452 - acc: 0.9461 - val_loss: 0.2298 - val_acc: 0.9243
# Epoch 9/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.1306 - acc: 0.9517 - val_loss: 0.2344 - val_acc: 0.9250
# Epoch 10/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.1150 - acc: 0.9573 - val_loss: 0.2344 - val_acc: 0.9268
# Epoch 11/50
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.1031 - acc: 0.9615 - val_loss: 0.2621 - val_acc: 0.9252
# Epoch 12/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0880 - acc: 0.9666 - val_loss: 0.2644 - val_acc: 0.9275
# Epoch 13/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0840 - acc: 0.9683 - val_loss: 0.2639 - val_acc: 0.9240
# Epoch 14/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0718 - acc: 0.9735 - val_loss: 0.2939 - val_acc: 0.9250
# Epoch 15/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0671 - acc: 0.9750 - val_loss: 0.3158 - val_acc: 0.9227
# Epoch 16/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0660 - acc: 0.9754 - val_loss: 0.2863 - val_acc: 0.9287
# Epoch 17/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0297 - acc: 0.9908 - val_loss: 0.5371 - val_acc: 0.9208

# %%
val_acc_per_epoch = history.history['val_acc']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
model = make_model(best_hp)
model.fit(x_train, y_train, epochs=best_epoch)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  rescaling_2 (Rescaling)     (None, 28, 28, 1)         0
#
#  resizing_2 (Resizing)       (None, 64, 64, 1)         0
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 96)        960
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 96)        83040
#
#  max_pooling2d_7 (MaxPooling  (None, 32, 32, 96)       0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 96)        83040
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 96)        83040
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 96)       0
#  2D)
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 96)        83040
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 96)        83040
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 96)          83040
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 96)          83040
#
#  max_pooling2d_10 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  global_average_pooling2d_2   (None, 96)               0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 384)               37248
#
#  dropout_2 (Dropout)         (None, 384)               0
#
#  dense_5 (Dense)             (None, 10)                3850
#
# =================================================================
# Total params: 623,338
# Trainable params: 623,338
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.5245 - acc: 0.8015
# Epoch 2/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2892 - acc: 0.8943
# Epoch 3/16
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2422 - acc: 0.9108
# Epoch 4/16
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2146 - acc: 0.9223
# Epoch 5/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1938 - acc: 0.9280
# Epoch 6/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1756 - acc: 0.9353
# Epoch 7/16
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1556 - acc: 0.9433
# Epoch 8/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1404 - acc: 0.9474
# Epoch 9/16
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1232 - acc: 0.9545
# Epoch 10/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1136 - acc: 0.9580
# Epoch 11/16
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1014 - acc: 0.9625
# Epoch 12/16
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0898 - acc: 0.9660
# Epoch 13/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0834 - acc: 0.9692
# Epoch 14/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0754 - acc: 0.9724
# Epoch 15/16
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0700 - acc: 0.9740
# Epoch 16/16
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0669 - acc: 0.9753

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step

# %%
predictions
# Out:
# array([[ 12.013161 , -17.999102 ,  -6.568815 , ..., -15.967436 ,
#         -11.78236  , -20.91802  ],
#        [-20.935917 ,  25.675615 , -14.68352  , ..., -88.50092  ,
#         -41.144093 , -65.59056  ],
#        [ -2.1008587, -11.499158 ,   5.4000216, ..., -17.836561 ,
#         -13.009708 , -13.100741 ],
#        ...,
#        [ -8.112904 , -30.828669 , -26.849836 , ..., -15.497483 ,
#          23.34929  , -28.70831  ],
#        [-15.484258 , -13.723463 , -49.64977  , ..., -33.936764 ,
#          29.608875 , -36.317703 ],
#        [-10.180846 ,  10.040135 , -17.718328 , ..., -42.549023 ,
#         -10.354838 , -26.76474  ]], dtype=float32)

# %%
preds = np.argmax(predictions, axis=1)
preds
# Out:
# array([0, 1, 2, ..., 8, 8, 1])

# %%
y_test.values
# Out:
# array([0, 1, 2, ..., 8, 8, 1])

# %%
accuracy_score(y_test, preds)
# Out:
# 0.9299
