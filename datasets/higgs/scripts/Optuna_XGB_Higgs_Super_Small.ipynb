# %%
import os
#os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"]="0, 1, 2, 4"

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score
import optuna
import gc
xgb.__version__
# Out:
# /home/tunguz/.local/lib/python3.12/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# '2.1.2'

# %%
# !nvidia-smi
# Out:
# Fri Jan 10 09:03:06 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.06              Driver Version: 555.42.06      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 5000                Off |   00000000:01:00.0  On |                  N/A |
# | N/A   49C    P8              6W /  110W |     397MiB /  16384MiB |     17%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1636      G   /usr/lib/xorg/Xorg                             98MiB |
# |    0   N/A  N/A      1972      G   /usr/bin/gnome-shell                          114MiB |
# |    0   N/A  N/A      2779      G   /usr/bin/nautilus                              16MiB |
# |    0   N/A  N/A      2884      G   ...irefox/5437/usr/lib/firefox/firefox        163MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Quadro RTX 5000 (UUID: GPU-0dad801b-446c-e905-a909-c5a1dc218d05)

# %%
train_x = pd.read_csv('../input/higgs_small_roc/xgtrain_ss.csv')
test_x = pd.read_csv('../input/higgs_small_roc/xgval_ss.csv')

# %%
train_y = train_x['target']
train_x = train_x[train_x.columns.difference(['target'])]

test_y = test_x['target']
test_x = test_x[test_x.columns.difference(['target'])]

# %%
dtrain = xgb.DMatrix(train_x, train_y)

# %%
dtest = xgb.DMatrix(test_x, test_y)

# %%
num_round = 1000

# %%
def objective(trial):
        
    params = {
        'objective': trial.suggest_categorical('objective',['binary:logistic']),
        'tree_method': trial.suggest_categorical('tree_method',['hist']),  # 'gpu_hist','hist'
        'device': trial.suggest_categorical('device',['cuda']),

        'lambda': trial.suggest_float('lambda',1e-3,10.0, log=True),
        'alpha': trial.suggest_float('alpha',1e-3,10.0, log=True),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3,1.0),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.001,0.1, log=True),
        #'n_estimators': trial.suggest_categorical('n_estimators', [1000]),
        'max_depth': trial.suggest_categorical('max_depth', [3,5,7,9,11,13,15,17,20]),
        #'random_state': trial.suggest_categorical('random_state', [24,48,2020]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1,300),
        'eval_metric': trial.suggest_categorical('eval_metric',['logloss']),

    }

    output = xgb.train(params, dtrain, num_round)
    
    #booster = output['booster']  # booster is the trained model
    #booster.set_param({'predictor': 'gpu_predictor'})

    predictions = output.predict(dtest)
    
    #predictions = predictions.compute()

    roc = roc_auc_score(test_y, predictions)
    
    return roc

# %%
study = optuna.create_study(direction='maximize')
# Out:
# [I 2025-01-10 09:03:09,672] A new study created in memory with name: no-name-da8fb20c-9cf5-4ca3-b49b-e80e0ebd5579

# %%
# %%time
study.optimize(objective, n_trials=2)
# Out:
# [I 2025-01-10 09:03:11,320] Trial 0 finished with value: 0.7699487033371424 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.0032446799901623903, 'alpha': 1.2643835824095597, 'colsample_bytree': 0.8002904543125735, 'subsample': 0.737954475041446, 'learning_rate': 0.005715855155598703, 'max_depth': 3, 'min_child_weight': 79, 'eval_metric': 'logloss'}. Best is trial 0 with value: 0.7699487033371424.
# [I 2025-01-10 09:03:12,472] Trial 1 finished with value: 0.7465490578890817 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.0012826615839869498, 'alpha': 0.05048725119491934, 'colsample_bytree': 0.940229958683032, 'subsample': 0.8600259499683084, 'learning_rate': 0.0014583269117000388, 'max_depth': 5, 'min_child_weight': 184, 'eval_metric': 'logloss'}. Best is trial 0 with value: 0.7699487033371424.
# CPU times: user 2.73 s, sys: 187 ms, total: 2.92 s
# Wall time: 2.28 s

# %%
# %%time
study.optimize(objective, n_trials=1000)
# Out:
# [I 2025-01-10 09:03:15,565] Trial 2 finished with value: 0.7869756238017318 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.1805462149159607, 'alpha': 0.0013836111863006842, 'colsample_bytree': 0.7561514624457841, 'subsample': 0.8709006984791814, 'learning_rate': 0.01812245118310185, 'max_depth': 9, 'min_child_weight': 6, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:16,780] Trial 3 finished with value: 0.7748879710178369 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.0842300432513843, 'alpha': 0.0023413298737996295, 'colsample_bytree': 0.5797300394275516, 'subsample': 0.9421751462014964, 'learning_rate': 0.029313018930005205, 'max_depth': 11, 'min_child_weight': 213, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:18,248] Trial 4 finished with value: 0.7793769557291641 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.4478251408947144, 'alpha': 0.049160864158575075, 'colsample_bytree': 0.9207688551674518, 'subsample': 0.9572532238772571, 'learning_rate': 0.018967033881531092, 'max_depth': 11, 'min_child_weight': 151, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:19,653] Trial 5 finished with value: 0.7665449846551445 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.08451725512110789, 'alpha': 2.220234627606412, 'colsample_bytree': 0.41381079901882756, 'subsample': 0.5036107729833614, 'learning_rate': 0.08678281130085433, 'max_depth': 7, 'min_child_weight': 72, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:20,728] Trial 6 finished with value: 0.766896627141583 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.0025016834340566728, 'alpha': 0.7490998281212259, 'colsample_bytree': 0.790796333000615, 'subsample': 0.8619868132647964, 'learning_rate': 0.012182030262116473, 'max_depth': 5, 'min_child_weight': 268, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:21,734] Trial 7 finished with value: 0.7673810410022163 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.8220345357427707, 'alpha': 0.0021857705839524026, 'colsample_bytree': 0.6632305094379807, 'subsample': 0.7021284912099355, 'learning_rate': 0.011984114450326615, 'max_depth': 5, 'min_child_weight': 216, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:24,915] Trial 8 finished with value: 0.7840833467937328 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.4180557632611132, 'alpha': 0.041914186461700254, 'colsample_bytree': 0.849094857739433, 'subsample': 0.5469563245682608, 'learning_rate': 0.016390815577084467, 'max_depth': 11, 'min_child_weight': 9, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:26,539] Trial 9 finished with value: 0.7703868268002741 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.024580690214569927, 'alpha': 0.0027031991565619824, 'colsample_bytree': 0.917209053287452, 'subsample': 0.960629620430711, 'learning_rate': 0.07343982142912078, 'max_depth': 17, 'min_child_weight': 105, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:28,444] Trial 10 finished with value: 0.7662234600216102 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.7133996650470165, 'alpha': 0.01036578036369926, 'colsample_bytree': 0.3167301146696097, 'subsample': 0.6119394729155634, 'learning_rate': 0.003879395825132321, 'max_depth': 9, 'min_child_weight': 52, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:31,721] Trial 11 finished with value: 0.7786144985056448 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 8.984706226591811, 'alpha': 0.1919209074122809, 'colsample_bytree': 0.7344100655253365, 'subsample': 0.4275786458197471, 'learning_rate': 0.037154198771289254, 'max_depth': 9, 'min_child_weight': 3, 'eval_metric': 'logloss'}. Best is trial 2 with value: 0.7869756238017318.
# [I 2025-01-10 09:03:35,346] Trial 12 finished with value: 0.7880682136260712 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.11453205421643267, 'alpha': 0.014667757557757179, 'colsample_bytree': 0.5997406223417941, 'subsample': 0.5893190153988241, 'learning_rate': 0.005446035570979185, 'max_depth': 20, 'min_child_weight': 13, 'eval_metric': 'logloss'}. Best is trial 12 with value: 0.7880682136260712.
# [I 2025-01-10 09:03:37,797] Trial 13 finished with value: 0.7828564405754296 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.04679160420146498, 'alpha': 0.009852108672960649, 'colsample_bytree': 0.5461732045283886, 'subsample': 0.8018782410762115, 'learning_rate': 0.004797847692549375, 'max_depth': 20, 'min_child_weight': 41, 'eval_metric': 'logloss'}. Best is trial 12 with value: 0.7880682136260712.
# [I 2025-01-10 09:03:39,195] Trial 14 finished with value: 0.7488423688564144 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.014568030282876229, 'alpha': 0.0011333792084696733, 'colsample_bytree': 0.4959350622123755, 'subsample': 0.633678652015282, 'learning_rate': 0.0014218591891018608, 'max_depth': 20, 'min_child_weight': 123, 'eval_metric': 'logloss'}. Best is trial 12 with value: 0.7880682136260712.
# [I 2025-01-10 09:03:41,275] Trial 15 finished with value: 0.7821453703081311 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.19648030033939218, 'alpha': 8.648772645841769, 'colsample_bytree': 0.6770999764706804, 'subsample': 0.6237909169712575, 'learning_rate': 0.006994280813259948, 'max_depth': 13, 'min_child_weight': 41, 'eval_metric': 'logloss'}. Best is trial 12 with value: 0.7880682136260712.
# [I 2025-01-10 09:03:50,685] Trial 16 finished with value: 0.7833621034741877 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 8.370992894122447, 'alpha': 0.011885428090898513, 'colsample_bytree': 0.6063700871578851, 'subsample': 0.7933544378251242, 'learning_rate': 0.002791402679194928, 'max_depth': 15, 'min_child_weight': 2, 'eval_metric': 'logloss'}. Best is trial 12 with value: 0.7880682136260712.
# [I 2025-01-10 09:03:51,444] Trial 17 finished with value: 0.7030679878926631 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.0661293728464973, 'alpha': 0.007079685496162182, 'colsample_bytree': 0.4565553173614878, 'subsample': 0.40962123562953545, 'learning_rate': 0.0026503023284499216, 'max_depth': 9, 'min_child_weight': 296, 'eval_metric': 'logloss'}. Best is trial 12 with value: 0.7880682136260712.
# [I 2025-01-10 09:03:52,681] Trial 18 finished with value: 0.7742163890480169 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.00913207496526684, 'alpha': 0.1696455808295248, 'colsample_bytree': 0.7172779745618385, 'subsample': 0.5614267284056712, 'learning_rate': 0.04576486115721128, 'max_depth': 20, 'min_child_weight': 112, 'eval_metric': 'logloss'}. Best is trial 12 with value: 0.7880682136260712.
# [I 2025-01-10 09:03:55,502] Trial 19 finished with value: 0.781992874850389 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.17021442156067307, 'alpha': 0.022005972248041256, 'colsample_bytree': 0.3580633349132141, 'subsample': 0.8830619013533003, 'learning_rate': 0.007251553840985277, 'max_depth': 17, 'min_child_weight': 31, 'eval_metric': 'logloss'}. Best is trial 12 with value: 0.7880682136260712.
# [I 2025-01-10 09:03:57,369] Trial 20 finished with value: 0.7810249299975621 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda':
 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:06:53,531] Trial 92 finished with value: 0.7862616641468131 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.026283654971234898, 'alpha': 0.014247042528001802, 'colsample_bytree': 0.6221932389670622, 'subsample': 0.8654384955142691, 'learning_rate': 0.010076078197177561, 'max_depth': 20, 'min_child_weight': 11, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:06:56,409] Trial 93 finished with value: 0.7864689777085752 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.0077030296105031325, 'alpha': 0.007263609908193416, 'colsample_bytree': 0.5930697058669592, 'subsample': 0.5340002850548649, 'learning_rate': 0.007926696831847579, 'max_depth': 20, 'min_child_weight': 19, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:06:59,539] Trial 94 finished with value: 0.7874806847447358 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.04893205535979484, 'alpha': 0.046332505813787825, 'colsample_bytree': 0.7227135518374459, 'subsample': 0.8518843251254072, 'learning_rate': 0.006012929027310212, 'max_depth': 20, 'min_child_weight': 27, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:00,883] Trial 95 finished with value: 0.7840422733461015 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.013273252580597568, 'alpha': 0.03107998684549126, 'colsample_bytree': 0.5667627504321362, 'subsample': 0.9682721481255869, 'learning_rate': 0.013799619165898305, 'max_depth': 5, 'min_child_weight': 36, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:05,074] Trial 96 finished with value: 0.7860303927460318 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.0063686206458238035, 'alpha': 0.02056402434980431, 'colsample_bytree': 0.6771897096355348, 'subsample': 0.7951821326402174, 'learning_rate': 0.016533315658640545, 'max_depth': 13, 'min_child_weight': 7, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:08,156] Trial 97 finished with value: 0.7880146997595187 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.6438579115563857, 'alpha': 0.07057565432311287, 'colsample_bytree': 0.6442875683164095, 'subsample': 0.7785908075308492, 'learning_rate': 0.007222123710822439, 'max_depth': 11, 'min_child_weight': 18, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:10,853] Trial 98 finished with value: 0.7875679081335258 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.8580463075102306, 'alpha': 0.026285961620502354, 'colsample_bytree': 0.6427833688173815, 'subsample': 0.7565705015825863, 'learning_rate': 0.009188048972279877, 'max_depth': 11, 'min_child_weight': 25, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:11,869] Trial 99 finished with value: 0.7629442458547822 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.5654921750803139, 'alpha': 0.08097810050069862, 'colsample_bytree': 0.5868847803356242, 'subsample': 0.44497793372633315, 'learning_rate': 0.011417456069946227, 'max_depth': 11, 'min_child_weight': 152, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:14,163] Trial 100 finished with value: 0.7831389183457051 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.886471202182225, 'alpha': 0.07008775895513482, 'colsample_bytree': 0.50872576876653, 'subsample': 0.7842215777349756, 'learning_rate': 0.020128132229978488, 'max_depth': 11, 'min_child_weight': 42, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:17,472] Trial 101 finished with value: 0.7881156276743139 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.23574276443547895, 'alpha': 0.05726748565890793, 'colsample_bytree': 0.6650791466330274, 'subsample': 0.8739273727303831, 'learning_rate': 0.006939477987965592, 'max_depth': 11, 'min_child_weight': 16, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:22,022] Trial 102 finished with value: 0.7876401227588434 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.23086022288469843, 'alpha': 0.03965327568294305, 'colsample_bytree': 0.6102009407225016, 'subsample': 0.8319515191494501, 'learning_rate': 0.006908158390155038, 'max_depth': 11, 'min_child_weight': 6, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:29,836] Trial 103 finished with value: 0.7888032617975802 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.6892654440491504, 'alpha': 0.05760327171730154, 'colsample_bytree': 0.6629178264762573, 'subsample': 0.678467094416668, 'learning_rate': 0.0057430411689235825, 'max_depth': 11, 'min_child_weight': 1, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:37,176] Trial 104 finished with value: 0.7883685293518643 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.15517133854882095, 'alpha': 0.0568522389430714, 'colsample_bytree': 0.655641733872321, 'subsample': 0.5795375289903993, 'learning_rate': 0.005268196546883702, 'max_depth': 11, 'min_child_weight': 1, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:45,157] Trial 105 finished with value: 0.7875082141878965 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.14899001422731015, 'alpha': 0.05315423559660651, 'colsample_bytree': 0.6546354763184077, 'subsample': 0.6890315699758802, 'learning_rate': 0.005280744269278249, 'max_depth': 11, 'min_child_weight': 1, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# [I 2025-01-10 09:07:49,539] Trial 106 finished with value: 0.7885693819218642 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 0.3616098753347952, 'alpha': 0.1212888503596796, 'colsample_bytree': 0.6876223664051946, 'subsample': 0.6338617727465847, 'learning_rate': 0.004453839380625624, 'max_depth': 11, 'min_child_weight': 7, 'eval_metric': 'logloss'}. Best is trial 33 with value: 0.7891023334814814.
# ...
# [I 2025-01-10 10:36:58,643] Trial 968 finished with value: 0.7904102830094979 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.5048974044886645, 'alpha': 0.018390818995476278, 'colsample_bytree': 0.984359764477924, 'subsample': 0.7849769522620715, 'learning_rate': 0.010509829248719819, 'max_depth': 7, 'min_child_weight': 11, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:01,747] Trial 969 finished with value: 0.7908266959350931 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.488553605283081, 'alpha': 0.022410082522004975, 'colsample_bytree': 0.9988827431809761, 'subsample': 0.7757213798091122, 'learning_rate': 0.00953030019363792, 'max_depth': 7, 'min_child_weight': 16, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:04,691] Trial 970 finished with value: 0.7880951210482858 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.7315343910371146, 'alpha': 0.021802222051559027, 'colsample_bytree': 0.999628828901284, 'subsample': 0.7908950866980425, 'learning_rate': 0.010782488508017465, 'max_depth': 7, 'min_child_weight': 23, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:07,755] Trial 971 finished with value: 0.7900007725098847 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.531623038856336, 'alpha': 0.016065576330013213, 'colsample_bytree': 0.9849401815166173, 'subsample': 0.7759479413263307, 'learning_rate': 0.00969747197480581, 'max_depth': 7, 'min_child_weight': 17, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:10,872] Trial 972 finished with value: 0.7889862764120628 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.6464208204624526, 'alpha': 0.04664734552163155, 'colsample_bytree': 0.9828242474562702, 'subsample': 0.7568999958015429, 'learning_rate': 0.01144360076097645, 'max_depth': 7, 'min_child_weight': 14, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:14,108] Trial 973 finished with value: 0.7907200895710162 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.9306812300723624, 'alpha': 0.020156291409666464, 'colsample_bytree': 0.9849715690704106, 'subsample': 0.7861781844885799, 'learning_rate': 0.010102581732213683, 'max_depth': 7, 'min_child_weight': 11, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:16,979] Trial 974 finished with value: 0.7881504207169092 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.83859920563567, 'alpha': 0.020984649137694454, 'colsample_bytree': 0.9853801043749106, 'subsample': 0.785058124348588, 'learning_rate': 0.011190102899400327, 'max_depth': 7, 'min_child_weight': 26, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:20,004] Trial 975 finished with value: 0.7884904454572906 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.457882990495432, 'alpha': 0.03096451045105309, 'colsample_bytree': 0.9988776830587237, 'subsample': 0.7890312293147899, 'learning_rate': 0.01027594894588973, 'max_depth': 7, 'min_child_weight': 19, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:22,831] Trial 976 finished with value: 0.7865784935254642 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.9945265289348288, 'alpha': 0.017794690776369797, 'colsample_bytree': 0.9868963309983098, 'subsample': 0.7709760136222229, 'learning_rate': 0.011874693431642921, 'max_depth': 7, 'min_child_weight': 28, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:25,799] Trial 977 finished with value: 0.7888882178196962 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.8176705928136787, 'alpha': 0.024449598945535573, 'colsample_bytree': 0.9814902428565926, 'subsample': 0.7782886524508829, 'learning_rate': 0.010017410648777581, 'max_depth': 7, 'min_child_weight': 22, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:28,914] Trial 978 finished with value: 0.7898489592686639 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.2395471362628223, 'alpha': 0.01343994473956556, 'colsample_bytree': 0.9806952826530536, 'subsample': 0.7913435815834697, 'learning_rate': 0.010736752442428008, 'max_depth': 7, 'min_child_weight': 14, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:31,999] Trial 979 finished with value: 0.7892961030387731 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.8529272923394755, 'alpha': 0.019938378843277538, 'colsample_bytree': 0.9985219866274523, 'subsample': 0.7580534754357917, 'learning_rate': 0.009602795801479304, 'max_depth': 7, 'min_child_weight': 16, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:34,982] Trial 980 finished with value: 0.7885988376234385 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.8942982771776677, 'alpha': 0.0325368347888672, 'colsample_bytree': 0.9813967482678855, 'subsample': 0.7901995133521347, 'learning_rate': 0.009265947827952835, 'max_depth': 7, 'min_child_weight': 22, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:38,199] Trial 981 finished with value: 0.790243842243449 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.352103525248838, 'alpha': 0.015664248442418836, 'colsample_bytree': 0.9856224566056083, 'subsample': 0.7725722426955284, 'learning_rate': 0.010699212386374245, 'max_depth': 7, 'min_child_weight': 11, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:39,861] Trial 982 finished with value: 0.7736287197103389 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 3.0705791571620424, 'alpha': 0.02341806230575087, 'colsample_bytree': 0.9787803332836912, 'subsample': 0.791393394247272, 'learning_rate': 0.05309875520782212, 'max_depth': 7, 'min_child_weight': 188, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:43,018] Trial 983 finished with value: 0.7894223331604383 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.1713152566212326, 'alpha': 0.027792856854106186, 'colsample_bytree': 0.9864959394604995, 'subsample': 0.7654908831381263, 'learning_rate': 0.01172485312181681, 'max_depth': 7, 'min_child_weight': 11, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:46,060] Trial 984 finished with value: 0.7893070185031168 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 3.0507740212383956, 'alpha': 0.022030990238728107, 'colsample_bytree': 0.9980077586691863, 'subsample': 0.783256917271997, 'learning_rate': 0.009972370820636917, 'max_depth': 7, 'min_child_weight': 18, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:48,771] Trial 985 finished with value: 0.7860367734770268 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.5401356472920136, 'alpha': 0.01777655344277111, 'colsample_bytree': 0.9986415819425524, 'subsample': 0.758545796775379, 'learning_rate': 0.00894311525664535, 'max_depth': 7, 'min_child_weight': 42, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:51,991] Trial 986 finished with value: 0.7900182492919496 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.0502818126619724, 'alpha': 0.013919125201565638, 'colsample_bytree': 0.9784520583907883, 'subsample': 0.776008295773265, 'learning_rate': 0.010103699229717437, 'max_depth': 7, 'min_child_weight': 11, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:55,245] Trial 987 finished with value: 0.7890729379754822 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.4535716878741685, 'alpha': 0.019020620915683985, 'colsample_bytree': 0.9996831303941264, 'subsample': 0.7947465604578416, 'learning_rate': 0.01166866737181713, 'max_depth': 7, 'min_child_weight': 9, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:37:58,331] Trial 988 finished with value: 0.7886843153405415 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 3.1831919822382764, 'alpha': 0.03726959042886826, 'colsample_bytree': 0.9763290361250658, 'subsample': 0.776235599676555, 'learning_rate': 0.00879564448460568, 'max_depth': 7, 'min_child_weight': 18, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:01,129] Trial 989 finished with value: 0.7871411816993412 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.6858932316138402, 'alpha': 0.02744603949007782, 'colsample_bytree': 0.9849296627230081, 'subsample': 0.7935810767325991, 'learning_rate': 0.009437642150100428, 'max_depth': 7, 'min_child_weight': 34, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:04,471] Trial 990 finished with value: 0.7891606830592595 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.3405486611553976, 'alpha': 0.0395884729015596, 'colsample_bytree': 0.9778218586199918, 'subsample': 0.7645502377116068, 'learning_rate': 0.010930746331719152, 'max_depth': 7, 'min_child_weight': 8, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:07,651] Trial 991 finished with value: 0.7896989719598977 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 3.3767041347920457, 'alpha': 0.021644116477444252, 'colsample_bytree': 0.9870860543620805, 'subsample': 0.7833164990473209, 'learning_rate': 0.008434405419553398, 'max_depth': 7, 'min_child_weight': 15, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:11,071] Trial 992 finished with value: 0.7909047896616106 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.7545208674619155, 'alpha': 0.01551180567501458, 'colsample_bytree': 0.9794508896803001, 'subsample': 0.7696969673161813, 'learning_rate': 0.010092933800366499, 'max_depth': 7, 'min_child_weight': 7, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:14,256] Trial 993 finished with value: 0.7897363132818527 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.805774178981201, 'alpha': 0.015491851118752993, 'colsample_bytree': 0.9768066509784513, 'subsample': 0.7553297845356743, 'learning_rate': 0.009417493083259123, 'max_depth': 7, 'min_child_weight': 13, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:17,162] Trial 994 finished with value: 0.7881574234688503 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.0395592324438083, 'alpha': 0.012430015000565361, 'colsample_bytree': 0.9998267982441359, 'subsample': 0.7501034174610706, 'learning_rate': 0.010285662316604131, 'max_depth': 7, 'min_child_weight': 24, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:20,024] Trial 995 finished with value: 0.7869048940006079 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.6317702574054556, 'alpha': 0.016433504842231498, 'colsample_bytree': 0.9757526062383006, 'subsample': 0.7696376298480857, 'learning_rate': 0.009009155967209338, 'max_depth': 7, 'min_child_weight': 29, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:23,096] Trial 996 finished with value: 0.7900344820321223 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 3.1001625680563683, 'alpha': 0.01951201204832291, 'colsample_bytree': 0.9867460454225545, 'subsample': 0.777529210774768, 'learning_rate': 0.00988495583990035, 'max_depth': 7, 'min_child_weight': 17, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:26,108] Trial 997 finished with value: 0.7885990583405484 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.2799389821087144, 'alpha': 0.02376128987168982, 'colsample_bytree': 0.9756952186560078, 'subsample': 0.7577396259454267, 'learning_rate': 0.008332466745117086, 'max_depth': 7, 'min_child_weight': 21, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:29,463] Trial 998 finished with value: 0.7899681665731964 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 2.9454432972581537, 'alpha': 0.02981888310411103, 'colsample_bytree': 0.9869666807941693, 'subsample': 0.789580765005016, 'learning_rate': 0.009269488848000877, 'max_depth': 7, 'min_child_weight': 9, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:32,868] Trial 999 finished with value: 0.7907011480299493 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.6824093858585305, 'alpha': 0.012816742812940735, 'colsample_bytree': 0.9982017764178349, 'subsample': 0.7699689183241565, 'learning_rate': 0.008301020169047447, 'max_depth': 7, 'min_child_weight': 8, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:36,338] Trial 1000 finished with value: 0.7904405011883611 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.2705322187419634, 'alpha': 0.010667711583957434, 'colsample_bytree': 0.9998438692407312, 'subsample': 0.7669576944387453, 'learning_rate': 0.008038347527929368, 'max_depth': 7, 'min_child_weight': 7, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# [I 2025-01-10 10:38:37,828] Trial 1001 finished with value: 0.7632646669027672 and parameters: {'objective': 'binary:logistic', 'tree_method': 'hist', 'device': 'cuda', 'lambda': 1.5783701593699913, 'alpha': 0.014032077149876773, 'colsample_bytree': 0.9776398124472574, 'subsample': 0.7680213544498115, 'learning_rate': 0.008145591443476609, 'max_depth': 7, 'min_child_weight': 255, 'eval_metric': 'logloss'}. Best is trial 935 with value: 0.7913630585773177.
# CPU times: user 1h 41min 22s, sys: 9.72 s, total: 1h 41min 32s
# Wall time: 1h 35min 25s

# %%
study.best_trial.params
# Out:
# {'objective': 'binary:logistic',
#  'tree_method': 'hist',
#  'device': 'cuda',
#  'lambda': 4.081123667487544,
#  'alpha': 0.018948321322930495,
#  'colsample_bytree': 0.9959299202093657,
#  'subsample': 0.7749822047878192,
#  'learning_rate': 0.00945751906853162,
#  'max_depth': 7,
#  'min_child_weight': 1,
#  'eval_metric': 'logloss'}

# %%
real_test_x = pd.read_csv('../input/higgs_small_roc/xgtest_ss.csv')

# %%
real_test_y = real_test_x['target']
real_test_x = real_test_x[real_test_x.columns.difference(['target'])]

# %%
drealtest = xgb.DMatrix(real_test_x, real_test_y)

# %%
params = study.best_trial.params

output = xgb.train(params, dtrain, num_round)
    


predictions = output.predict(drealtest)
    
roc_auc_score(real_test_y, predictions)
# Out:
# 0.7841266979088475

# %%
# %%time
params = study.best_trial.params
params['seed'] = 2022

output = xgb.train(params, dtrain, num_round)

predictions = output.predict(drealtest)
    
roc_auc_score(real_test_y, predictions)
# Out:
# CPU times: user 3.11 s, sys: 12 ms, total: 3.12 s
# Wall time: 2.75 s
# 0.783972180239104

# %%
# %%time 
scores = []

for jj in range(15):
    print(jj)
    params = study.best_trial.params
    params['seed'] = 5*jj**3 + 137

    output = xgb.dask.train(client, params, dtrain, num_round)

    booster = output['booster']  # booster is the trained model
    booster.set_param({'predictor': 'gpu_predictor'})

    predictions = xgb.dask.predict(client, booster, drealtest)

    predictions = predictions.compute()

    scores.append(roc_auc_score(real_test_y, predictions))
# Out:
# 0
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 1
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 2
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 3
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 4
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 5
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 6
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 7
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 8
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 9
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 10
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 11
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 12
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 13
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# 14
# /home/tunguz/anaconda3/lib/python3.7/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# CPU times: user 23.5 s, sys: 4.35 s, total: 27.9 s
# Wall time: 5min 9s

# %%
scores
# Out:
# [0.8067397221533028,
#  0.8066990070642219,
#  0.8063826106965943,
#  0.8064383115265237,
#  0.8064385880739696,
#  0.8062720699863317,
#  0.8067426754713112,
#  0.8064104376311154,
#  0.8061099140433141,
#  0.8061604909186776,
#  0.8066853310103347,
#  0.8062528838550297,
#  0.8066905749760565,
#  0.8061511717915344,
#  0.8065482678346361]

# %%
import numpy as np
np.mean(scores)
# Out:
# 0.8064481371355302
