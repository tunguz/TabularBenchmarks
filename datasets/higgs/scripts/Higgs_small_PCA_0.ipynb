# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2024-03-02T10:36:01.744156-05:00
#
# Python implementation: CPython
# Python version       : 3.9.6
# IPython version      : 8.10.0
#
# Compiler    : Clang 15.0.0 (clang-1500.0.40.1)
# OS          : Darwin
# Release     : 23.0.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 20
# Architecture: 64bit

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
# %watermark --iversions
# Out:
# numpy : 1.26.4
# pandas: 2.2.0

# %%
X_num_train = np.load('../input/higgs_small_roc/X_num_train.npy')
X_num_val = np.load('../input/higgs_small_roc/X_num_val.npy')
X_num_test = np.load('../input/higgs_small_roc/X_num_test.npy')

y_train = np.load('../input/higgs_small_roc/y_train.npy')
y_val = np.load('../input/higgs_small_roc/y_val.npy')
y_test = np.load('../input/higgs_small_roc/y_test.npy')

# %%
X_num_train.shape
# Out:
# (62751, 28)

# %%
pca = PCA()

# %%
# %%time
pca.fit(X_num_train)
# Out:
# CPU times: user 223 ms, sys: 113 ms, total: 336 ms
# Wall time: 57.1 ms
# PCA()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.11596388 0.09627638 0.08481582 0.07022457 0.06450196 0.05657556
#  0.05575919 0.05470806 0.05321743 0.04461437 0.04197576 0.04090164
#  0.03881702 0.03764822 0.02569097 0.02124492 0.01962641 0.0184736
#  0.01637042 0.01049686 0.00790042 0.00716588 0.00586833 0.00526479
#  0.00296672 0.00136293 0.00109627 0.00047156]

# %%
print(pca.singular_values_)
# Out:
# [377.59265  344.05038  322.9242   293.83716  281.61035  263.74036
#  261.8306   259.35092  255.79326  234.20682  227.17546  224.25003
#  218.46066  215.14655  177.7266   161.618    155.33974  150.70857
#  141.87048  113.60352   98.55695   93.86352   84.94142   80.45497
#   60.39488   40.935413  36.713047  24.078676]

# %%
# %%time
pca.transform(X_num_val)
# Out:
# CPU times: user 88.4 ms, sys: 6.91 ms, total: 95.3 ms
# Wall time: 21.7 ms
# array([[-0.5827419 ,  0.23980756, -1.0097121 , ..., -0.03476856,
#          0.00797735,  0.02219143],
#        [ 2.109921  ,  2.6439185 , -0.62603563, ...,  0.22882664,
#         -0.16121776,  0.04641763],
#        [ 2.1028435 ,  2.9253535 , -0.6832978 , ...,  0.01591685,
#          0.01497708, -0.01034204],
#        ...,
#        [-0.7514662 , -2.6073444 , -1.4708456 , ...,  0.06418089,
#         -0.08882884,  0.04447759],
#        [-1.0829091 , -1.1219068 ,  1.8300887 , ..., -0.02682433,
#         -0.0766632 ,  0.15595737],
#        [-1.4008886 , -0.99828666,  1.0611196 , ...,  0.10634672,
#          0.05069897, -0.05681957]], dtype=float32)

# %%
# %%time
pca.transform(X_num_test)
# Out:
# CPU times: user 70.4 ms, sys: 31.2 ms, total: 102 ms
# Wall time: 18.1 ms
# array([[ 2.3026452e+00, -5.5363345e-01, -5.7832408e-01, ...,
#         -9.6652191e-03, -4.0588282e-02, -7.4122824e-02],
#        [ 2.4365978e+00, -1.6872244e+00, -7.7786170e-02, ...,
#          1.3963260e-01, -1.3471243e-01,  1.3596269e-01],
#        [ 2.1536088e+00,  6.7221023e-02, -7.0476025e-01, ...,
#          3.4672201e-02,  5.3837650e-02, -1.6386001e-03],
#        ...,
#        [-1.2699097e+00, -8.3108890e-01,  1.3850251e+00, ...,
#          3.1715456e-02, -5.7491653e-02, -1.1484186e-01],
#        [-8.9776570e-01, -1.4691750e+00,  1.3340942e-02, ...,
#         -4.2194495e-01, -1.8123483e-02,  2.5406599e-01],
#        [-9.4677740e-01, -3.4871531e-01,  3.1727102e-01, ...,
#         -2.9564714e-01,  1.8199117e-01,  1.4149702e-01]], dtype=float32)
