# %%
import os
#os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"]="0, 1, 2, 4"

# %%
from dask.distributed import Client
from dask_cuda import LocalCUDACluster
from dask import dataframe as dd
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score
import optuna
import gc
xgb.__version__
# Out:
# '1.6.2'

# %%
# !nvidia-smi
# Out:
# Mon Jan  9 21:37:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA TITAN RTX    On   | 00000000:09:00.0 Off |                  N/A |
# | 41%   35C    P8    32W / 280W |    905MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA TITAN RTX    On   | 00000000:41:00.0  On |                  N/A |
# | 41%   34C    P8    32W / 280W |    364MiB / 24217MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1301      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A    192312      C   /usr/bin/python3                  869MiB |
# |    1   N/A  N/A      1301      G   /usr/lib/xorg/Xorg                161MiB |
# |    1   N/A  N/A      1556      G   /usr/bin/gnome-shell               29MiB |
# |    1   N/A  N/A      2380      G   ...mviewer/tv_bin/TeamViewer       18MiB |
# |    1   N/A  N/A      2707      G   /usr/lib/firefox/firefox          142MiB |
# |    1   N/A  N/A     19633      G   /usr/lib/firefox/firefox            3MiB |
# +-----------------------------------------------------------------------------+

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA TITAN RTX (UUID: GPU-0eb32f58-b8d5-17c0-e952-f4ec26a9353f)
# GPU 1: NVIDIA TITAN RTX (UUID: GPU-50aeb092-88f5-4e0b-7f73-32741666f319)

# %%
train_x = dd.read_csv('../input/higgs_small_roc/xgtrain_aug_25.csv')
test_x = dd.read_csv('../input/higgs_small_roc/xgval_aug.csv')

# %%
train_y = train_x['target']
train_x = train_x[train_x.columns.difference(['target'])]

test_y = test_x['target']
test_x = test_x[test_x.columns.difference(['target'])]

# %%
cluster = LocalCUDACluster(n_workers=2)
client = Client(cluster)
# Out:
# 2023-01-09 21:37:57,122 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-01-09 21:37:57,123 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# 2023-01-09 21:37:57,146 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-01-09 21:37:57,146 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize

# %%
dtrain = xgb.dask.DaskDMatrix(client, train_x, train_y)

# %%
dtest = xgb.dask.DaskDMatrix(client, test_x, test_y)

# %%
num_round = 1000

# %%
def objective(trial):
        
    params = {
        'objective': trial.suggest_categorical('objective',['binary:logistic']),
        'tree_method': trial.suggest_categorical('tree_method',['gpu_hist']),  # 'gpu_hist','hist'
        'lambda': trial.suggest_loguniform('lambda',1e-3,10.0),
        'alpha': trial.suggest_loguniform('alpha',1e-3,10.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.3,1.0),
        'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001,0.1),
        #'n_estimators': trial.suggest_categorical('n_estimators', [1000]),
        'max_depth': trial.suggest_categorical('max_depth', [3,5,7,9,11,13,15,17,20]),
        #'random_state': trial.suggest_categorical('random_state', [24,48,2020]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1,300),
        'eval_metric': trial.suggest_categorical('eval_metric',['logloss']),

    }

    output = xgb.dask.train(client, params, dtrain, num_round)
    
    booster = output['booster']  # booster is the trained model
    booster.set_param({'predictor': 'gpu_predictor'})

    predictions = xgb.dask.predict(client, booster, dtest)
    
    predictions = predictions.compute()

    roc = roc_auc_score(test_y, predictions)
    
    return roc

# %%
study = optuna.create_study(direction='maximize')
# Out:
# [I 2023-01-09 21:38:01,794] A new study created in memory with name: no-name-9ca9fc5c-a72c-4c28-bd17-fccb2a68209d

# %%
# %%time
study.optimize(objective, n_trials=2)
# Out:
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:38:01] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [21:38:01] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 21:38:29,283] Trial 0 finished with value: 0.8011809749967193 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.12953960875828102, 'alpha': 9.207937126371373, 'colsample_bytree': 0.9223180647491764, 'subsample': 0.8175238469989368, 'learning_rate': 0.0029891504706391282, 'max_depth': 9, 'min_child_weight': 262, 'eval_metric': 'logloss'}. Best is trial 0 with value: 0.8011809749967193.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:38:29] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [21:38:29] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 21:38:32,602] Trial 1 finished with value: 0.7984630158229491 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.009260974084803478, 'alpha': 2.1695818303826777, 'colsample_bytree': 0.9990296075141631, 'subsample': 0.9511501698156367, 'learning_rate': 0.044779115553980786, 'max_depth': 3, 'min_child_weight': 231, 'eval_metric': 'logloss'}. Best is trial 0 with value: 0.8011809749967193.
# CPU times: user 1.2 s, sys: 769 ms, total: 1.97 s
# Wall time: 30.8 s

# %%
# %%time
study.optimize(objective, n_trials=100)
# Out:
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:38:32] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [21:38:32] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 21:38:35,958] Trial 2 finished with value: 0.7872497017331438 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.0014685210173758058, 'alpha': 0.1566296155004991, 'colsample_bytree': 0.36267754891812476, 'subsample': 0.4311259329526032, 'learning_rate': 0.015293863730239167, 'max_depth': 3, 'min_child_weight': 255, 'eval_metric': 'logloss'}. Best is trial 0 with value: 0.8011809749967193.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:38:35] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [21:38:35] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 21:38:41,048] Trial 3 finished with value: 0.8057171031811566 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.029274911600352015, 'alpha': 0.03078124335317221, 'colsample_bytree': 0.39718767279032297, 'subsample': 0.6902994250327423, 'learning_rate': 0.03264520891566011, 'max_depth': 5, 'min_child_weight': 266, 'eval_metric': 'logloss'}. Best is trial 3 with value: 0.8057171031811566.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:38:41] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [21:38:41] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 21:38:46,271] Trial 4 finished with value: 0.8078035281062212 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 9.379686516320655, 'alpha': 7.833402729084162, 'colsample_bytree': 0.8673900414959141, 'subsample': 0.429419337798732, 'learning_rate': 0.05300909736579071, 'max_depth': 5, 'min_child_weight': 64, 'eval_metric': 'logloss'}. Best is trial 4 with value: 0.8078035281062212.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:38:46] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [21:38:46] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 21:39:12,663] Trial 5 finished with value: 0.8016823476895374 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.3317435891679191, 'alpha': 0.011057081389956104, 'colsample_bytree': 0.6240495369403807, 'subsample': 0.9983111358610433, 'learning_rate': 0.002799034035937694, 'max_depth': 9, 'min_child_weight': 283, 'eval_metric': 'logloss'}. Best is trial 4 with value: 0.8078035281062212.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:39:12] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [21:39:12] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 21:42:03,978] Trial 6 finished with value: 0.8092003780612302 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.0029079278934172393, 'alpha': 0.007463957563634243, 'colsample_bytree': 0.6151020823288786, 'subsample': 0.9834390277631524, 'learning_rate': 0.0061517495818987356, 'max_depth': 20, 'min_child_weight': 139, 'eval_metric': 'logloss'}. Best is trial 6 with value: 0.8092003780612302.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [21:42:03] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [21:42:03] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 21
task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:10:05,134] Trial 24 finished with value: 0.810847588245377 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.008262959115676663, 'alpha': 3.0200917779041934, 'colsample_bytree': 0.6886144380255989, 'subsample': 0.89627372788081, 'learning_rate': 0.029104608245613284, 'max_depth': 20, 'min_child_weight': 238, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:10:05] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:10:05] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:11:06,322] Trial 25 finished with value: 0.8092076015587883 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.016915970210308075, 'alpha': 3.522587613012202, 'colsample_bytree': 0.553097923415143, 'subsample': 0.8562799556966336, 'learning_rate': 0.037939406051167454, 'max_depth': 20, 'min_child_weight': 296, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:11:06] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:11:06] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:11:59,767] Trial 26 finished with value: 0.8062823296356852 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.04295748480445907, 'alpha': 2.7327348834943446, 'colsample_bytree': 0.7915668952578461, 'subsample': 0.9400919501329733, 'learning_rate': 0.0730988598174362, 'max_depth': 20, 'min_child_weight': 241, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:11:59] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:11:59] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:12:09,818] Trial 27 finished with value: 0.8082312309074644 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.06379861073976394, 'alpha': 4.43739987566975, 'colsample_bytree': 0.47561898446914763, 'subsample': 0.8929044833039672, 'learning_rate': 0.01497779289460064, 'max_depth': 7, 'min_child_weight': 209, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:12:09] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:12:09] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:12:34,369] Trial 28 finished with value: 0.8113501431133032 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.17234853919407409, 'alpha': 0.2812638628199144, 'colsample_bytree': 0.5962381782912033, 'subsample': 0.8229267361302961, 'learning_rate': 0.02823294855829771, 'max_depth': 11, 'min_child_weight': 235, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:12:34] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:12:34] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:12:54,992] Trial 29 finished with value: 0.8079272569989332 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.31337241960663265, 'alpha': 0.3709681485101069, 'colsample_bytree': 0.5779423498088698, 'subsample': 0.8087865457381785, 'learning_rate': 0.05743460119613701, 'max_depth': 11, 'min_child_weight': 261, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:12:55] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:12:55] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:13:26,604] Trial 30 finished with value: 0.8106570623825814 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.1985107022950356, 'alpha': 9.93722936077538, 'colsample_bytree': 0.9244025668218734, 'subsample': 0.8285402123767833, 'learning_rate': 0.017254425742384224, 'max_depth': 11, 'min_child_weight': 162, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:13:26] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:13:26] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:14:11,662] Trial 31 finished with value: 0.8104262284250596 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.15531151203683194, 'alpha': 0.6835897859419859, 'colsample_bytree': 0.701490230437805, 'subsample': 0.9499823994319446, 'learning_rate': 0.029116094446395655, 'max_depth': 15, 'min_child_weight': 239, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:14:11] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:14:11] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:14:27,396] Trial 32 finished with value: 0.8095093007993526 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.01191086142193378, 'alpha': 0.22387676059029543, 'colsample_bytree': 0.6411261858113406, 'subsample': 0.8815099197361239, 'learning_rate': 0.043176852180875504, 'max_depth': 9, 'min_child_weight': 193, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:14:27] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:14:27] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:14:53,941] Trial 33 finished with value: 0.8100629990083426 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.006140275593309732, 'alpha': 2.3774043984468864, 'colsample_bytree': 0.5939513453526246, 'subsample': 0.9208232864665482, 'learning_rate': 0.02554073759948356, 'max_depth': 11, 'min_child_weight': 234, 'eval_metric': 'logloss'}. Best is trial 23 with value: 0.8114925177609988.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:14:53] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:14:53] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:16:11,951] Trial 34 finished with value: 0.8128388766094866 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.016258851543998167, 'alpha': 1.7642994995727697, 'colsample_bytree': 0.6586394819694826, 'subsample': 0.8166184895179339, 'learning_rate': 0.013460436828624106, 'max_depth': 20, 'min_child_weight': 274, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:16:11] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:16:11] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:17:32,084] Trial 35 finished with value: 0.8104121972294642 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.0019887530686325777, 'alpha': 0.15669199819347204, 'colsample_bytree': 0.48976914844899844, 'subsample': 0.8001491910890884, 'learning_rate': 0.012978135976664406, 'max_depth': 20, 'min_child_weight': 275, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:17:32] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:17:32] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:17:58,958] Trial 36 finished with value: 0.8119122469949599 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.06120100392739967, 'alpha': 5.572144717385363, 'colsample_bytree': 0.648855587020254, 'subsample': 0.8385745681757335, 'learning_rate': 0.018967135416568342, 'max_depth': 11, 'min_child_weight': 252, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:17:58] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:17:58] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:18:23,613] Trial 37 finished with value: 0.8116056559953269 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.04923025307663071, 'alpha': 6.601717243637181, 'colsample_bytree': 0.5769924922826859, 'subsample': 0.7128831107297339, 'learning_rate': 0.017208054027868035, 'max_depth': 11, 'min_child_weight': 298, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:18:23] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:18:23] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:18:48,525] Trial 38 finished with value: 0.8122007792506973 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.05620759597966129, 'alpha': 6.2068168691094705, 'colsample_bytree': 0.6380040442292436, 'subsample': 0.7037651043899184, 'learning_rate': 0.017075595850950955, 'max_depth': 11, 'min_child_weight': 279, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:18:48] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:18:48] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:19:20,099] Trial 39 finished with value: 0.8105469814976713 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.05640432144194335, 'alpha': 6.28986644999399, 'colsample_bytree': 0.5158806536230301, 'subsample': 0.6975961160120348, 'learning_rate': 0.009075301718809197, 'max_depth': 11, 'min_child_weight': 300, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:19:20] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:19:20] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:19:49,482] Trial 40 finished with value: 0.8098668394696864 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.09627409960406658, 'alpha': 7.864992716828378, 'colsample_bytree': 0.43968416581199576, 'subsample': 0.7327020723831307, 'learning_rate': 0.014287504708846944, 'max_depth': 11, 'min_child_weight': 282, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# [22:19:49] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:19:49] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:20:14,203] Trial 41 finished with value: 0.8118802956553091 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.02165973257262483, 'alpha': 5.5571521456762545, 'colsample_bytree': 0.6463089150814381, 'subsample': 0.6661324975581516, 'learning_rate': 0.017379876435329872, 'max_depth': 11, 'min_child_weight': 261, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:20:14] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:20:14] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:20:39,376] Trial 42 finished with value: 0.8117289527826543 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.022373576492610642, 'alpha': 5.9410117772310675, 'colsample_bytree': 0.6394998098077692, 'subsample': 0.6532142991160378, 'learning_rate': 0.016725056856222068, 'max_depth': 11, 'min_child_weight': 257, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:20:39] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:20:39] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:21:06,916] Trial 43 finished with value: 0.8119457555445806 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.024982840892435482, 'alpha': 9.901415090393094, 'colsample_bytree': 0.632543119676267, 'subsample': 0.6185795110953295, 'learning_rate': 0.012033808047061811, 'max_depth': 11, 'min_child_weight': 260, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# ...
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# /home/tunguz/.local/lib/python3.8/site-packages/distributed/worker_state_machine.py:3649: FutureWarning: The `Worker.nthreads` attribute has been moved to `Worker.state.nthreads`
#   warnings.warn(
# [22:38:45] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:38:45] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:39:56,284] Trial 82 finished with value: 0.8121697818040652 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.007606960252978564, 'alpha': 1.737776528359372, 'colsample_bytree': 0.6816727988368249, 'subsample': 0.7892019587485545, 'learning_rate': 0.015748260378267383, 'max_depth': 20, 'min_child_weight': 293, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:39:56] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:39:56] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:41:06,331] Trial 83 finished with value: 0.812327606257486 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.003172517959490974, 'alpha': 0.5040266016805685, 'colsample_bytree': 0.6774204334604296, 'subsample': 0.7946934467238334, 'learning_rate': 0.015244921246018004, 'max_depth': 20, 'min_child_weight': 300, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:41:06] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:41:06] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:42:20,193] Trial 84 finished with value: 0.811714693304969 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.0015883799502075505, 'alpha': 0.5017827186965766, 'colsample_bytree': 0.6774289165918352, 'subsample': 0.854615308303537, 'learning_rate': 0.015614548113352382, 'max_depth': 20, 'min_child_weight': 293, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:42:20] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:42:20] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:43:22,663] Trial 85 finished with value: 0.8112556424810271 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.00110742884641474, 'alpha': 1.2084196416927142, 'colsample_bytree': 0.7528620274258014, 'subsample': 0.7495008779699942, 'learning_rate': 0.022026124997484766, 'max_depth': 20, 'min_child_weight': 300, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:43:22] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:43:22] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:44:26,903] Trial 86 finished with value: 0.8106495779912064 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.002992459140786078, 'alpha': 1.6248064244378806, 'colsample_bytree': 0.6640011219215056, 'subsample': 0.7912969336057317, 'learning_rate': 0.027096071479087953, 'max_depth': 20, 'min_child_weight': 282, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:44:26] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:44:26] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:45:40,337] Trial 87 finished with value: 0.8121044849734294 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.003545772907568346, 'alpha': 2.032113221920316, 'colsample_bytree': 0.6523508232436043, 'subsample': 0.8197221840510803, 'learning_rate': 0.015488735689789505, 'max_depth': 20, 'min_child_weight': 289, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:45:40] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:45:40] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:47:01,138] Trial 88 finished with value: 0.8117280478072266 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.005189154837816195, 'alpha': 1.4545904955790023, 'colsample_bytree': 0.6133834426443121, 'subsample': 0.7811563592139298, 'learning_rate': 0.010232466912780309, 'max_depth': 20, 'min_child_weight': 278, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:47:01] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:47:01] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:48:11,142] Trial 89 finished with value: 0.8121302400849262 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.007264625521097607, 'alpha': 0.5153436033010697, 'colsample_bytree': 0.7291698301095803, 'subsample': 0.7535187892599542, 'learning_rate': 0.013816720208514889, 'max_depth': 20, 'min_child_weight': 292, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:48:11] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:48:11] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:49:41,485] Trial 90 finished with value: 0.811492582984453 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.0019274465090966416, 'alpha': 0.4041082242769074, 'colsample_bytree': 0.586068160545406, 'subsample': 0.8050550904787863, 'learning_rate': 0.008873212781385396, 'max_depth': 20, 'min_child_weight': 257, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:49:41] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:49:41] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:50:52,107] Trial 91 finished with value: 0.8119143993689502 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.007208945305981402, 'alpha': 0.15175820093183162, 'colsample_bytree': 0.7276023516815697, 'subsample': 0.7552131750698713, 'learning_rate': 0.013662130618343971, 'max_depth': 20, 'min_child_weight': 285, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:50:52] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:50:52] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:52:00,398] Trial 92 finished with value: 0.811495941992347 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.009522877796126173, 'alpha': 0.5409583048525114, 'colsample_bytree': 0.6986870695658352, 'subsample': 0.7858250215925288, 'learning_rate': 0.016501352083642416, 'max_depth': 20, 'min_child_weight': 300, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:52:00] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:52:00] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:53:06,139] Trial 93 finished with value: 0.8115719354694797 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.004402689787052969, 'alpha': 0.19560558379552084, 'colsample_bytree': 0.7659695722986272, 'subsample': 0.8315165965306378, 'learning_rate': 0.021824719607873157, 'max_depth': 20, 'min_child_weight': 293, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:53:06] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:53:06] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:54:10,267] Trial 94 finished with value: 0.8107043901515715 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.0035060244072256056, 'alpha': 2.430695117028643, 'colsample_bytree': 0.6781473768230355, 'subsample': 0.7338948415204605, 'learning_rate': 0.024924970076612055, 'max_depth': 20, 'min_child_weight': 275, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:54:10] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:54:10] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:54:46,902] Trial 95 finished with value: 0.8121177171817102 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.04873376497572402, 'alpha': 1.0501969133421862, 'colsample_bytree': 0.7427512584390145, 'subsample': 0.8698243046424865, 'learning_rate': 0.014880562504588295, 'max_depth': 13, 'min_child_weight': 282, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:54:46] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:54:46] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:55:44,382] Trial 96 finished with value: 0.8111113437414312 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.010456315837528696, 'alpha': 2.886343468388877, 'colsample_bytree': 0.8093555474169436, 'subsample': 0.8105425609421151, 'learning_rate': 0.013011221843445995, 'max_depth': 17, 'min_child_weight': 265, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:55:44] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:55:44] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:56:42,744] Trial 97 finished with value: 0.810633263974712 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.07227025988335921, 'alpha': 0.8648435189579196, 'colsample_bytree': 0.627527500301466, 'subsample': 0.7134876234242719, 'learning_rate': 0.03089874023626314, 'max_depth': 20, 'min_child_weight': 291, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:56:42] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:56:42] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:56:57,997] Trial 98 finished with value: 0.8112444974232822 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.0025825181479651586, 'alpha': 0.3108284249832291, 'colsample_bytree': 0.646412869834125, 'subsample': 0.6764380661155207, 'learning_rate': 0.018101260853166348, 'max_depth': 9, 'min_child_weight': 273, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:56:58] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:56:58] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:58:27,602] Trial 99 finished with value: 0.8101741316214526 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.10296451383172066, 'alpha': 1.3260678470322864, 'colsample_bytree': 0.9951964914096542, 'subsample': 0.7614717627786328, 'learning_rate': 0.006648707459191937, 'max_depth': 20, 'min_child_weight': 253, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:58:27] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:58:27] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:58:37,290] Trial 100 finished with value: 0.8075896277880092 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.005485450792253807, 'alpha': 0.6119185017060976, 'colsample_bytree': 0.7203561143800296, 'subsample': 0.7776421969644592, 'learning_rate': 0.011456727154398555, 'max_depth': 7, 'min_child_weight': 286, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:58:37] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:58:37] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# [I 2023-01-09 22:59:14,258] Trial 101 finished with value: 0.8119232371470009 and parameters: {'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'lambda': 0.03251148889794981, 'alpha': 1.025787000090246, 'colsample_bytree': 0.7466914611883465, 'subsample': 0.8797527992056918, 'learning_rate': 0.01530566927430167, 'max_depth': 13, 'min_child_weight': 280, 'eval_metric': 'logloss'}. Best is trial 34 with value: 0.8128388766094866.
# CPU times: user 2min 24s, sys: 1min 9s, total: 3min 34s
# Wall time: 1h 20min 41s

# %%
study.best_trial.params
# Out:
# {'objective': 'binary:logistic',
#  'tree_method': 'gpu_hist',
#  'lambda': 0.016258851543998167,
#  'alpha': 1.7642994995727697,
#  'colsample_bytree': 0.6586394819694826,
#  'subsample': 0.8166184895179339,
#  'learning_rate': 0.013460436828624106,
#  'max_depth': 20,
#  'min_child_weight': 274,
#  'eval_metric': 'logloss'}

# %%
real_test_x = dd.read_csv('../input/higgs_small_roc/xgtest.csv')

# %%
real_test_y = real_test_x['target']
real_test_x = real_test_x[real_test_x.columns.difference(['target'])]

# %%
drealtest = xgb.dask.DaskDMatrix(client, real_test_x, real_test_y)

# %%
params = study.best_trial.params

output = xgb.dask.train(client, params, dtrain, num_round)
    
booster = output['booster']  # booster is the trained model
booster.set_param({'predictor': 'gpu_predictor'})

predictions = xgb.dask.predict(client, booster, drealtest)
    
predictions = predictions.compute()

roc_auc_score(real_test_y, predictions)
# Out:
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [22:59:14] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [22:59:14] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 0.8058599621129998

# %%
# %%time 
scores = []

for jj in range(15):
    print(jj)
    params = study.best_trial.params
    params['seed'] = 5*jj**3 + 137

    output = xgb.dask.train(client, params, dtrain, num_round)

    booster = output['booster']  # booster is the trained model
    booster.set_param({'predictor': 'gpu_predictor'})

    predictions = xgb.dask.predict(client, booster, drealtest)

    predictions = predictions.compute()

    scores.append(roc_auc_score(real_test_y, predictions))
# Out:
# 0
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:00:32] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:00:32] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 1
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:01:49] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:01:49] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 2
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:03:08] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:03:08] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 3
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:04:26] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:04:26] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 4
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:05:45] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:05:45] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 5
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:07:03] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:07:03] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 6
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:08:21] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:08:21] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 7
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:09:38] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:09:38] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 8
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:10:57] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:10:57] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 9
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:12:15] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:12:15] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 10
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:13:33] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:13:33] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 11
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:14:51] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:14:51] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 12
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:16:09] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:16:09] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 13
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:17:27] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:17:27] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# 14
# /home/tunguz/.local/lib/python3.8/site-packages/xgboost/dask.py:884: RuntimeWarning: coroutine 'Client._wait_for_workers' was never awaited
#   client.wait_for_workers(n_workers)
# [23:18:45] task [xgboost.dask-0]:tcp://127.0.0.1:38053 got new rank 0
# [23:18:45] task [xgboost.dask-1]:tcp://127.0.0.1:46637 got new rank 1
# CPU times: user 30.9 s, sys: 18.8 s, total: 49.6 s
# Wall time: 19min 31s

# %%
scores
# Out:
# [0.806064346329237,
#  0.806149783836428,
#  0.8062990359712568,
#  0.8064492064523214,
#  0.8060648681168711,
#  0.8056599400413831,
#  0.8054376167662889,
#  0.806007252326325,
#  0.8067147650507688,
#  0.8070762125627157,
#  0.8069742030802689,
#  0.8061540259698925,
#  0.8056558074833218,
#  0.8063920759242751,
#  0.8064956507696237]

# %%
import numpy as np
np.mean(scores)
# Out:
# 0.8062396527120652
