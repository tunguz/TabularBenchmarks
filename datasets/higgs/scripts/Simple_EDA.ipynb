# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2023-04-05T07:27:21.802253-04:00
#
# Python implementation: CPython
# Python version       : 3.9.6
# IPython version      : 8.10.0
#
# Compiler    : Clang 14.0.0 (clang-1400.0.29.202)
# OS          : Darwin
# Release     : 22.3.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 20
# Architecture: 64bit

# %%
import pandas as pd
import polars as pl

# %%
# %watermark --iversions
# Out:
# polars: 0.16.18
# pandas: 2.0.0

# %%
# %%time

higgs = pd.read_csv('../input/HIGGS.csv.gz', header=None, engine='pyarrow', dtype_backend='pyarrow')
higgs.head()
# Out:
# CPU times: user 45.6 s, sys: 8.25 s, total: 53.9 s
# Wall time: 26.7 s
#     0         1         2         3         4         5         6         7
# 0  1.0  0.869293 -0.635082  0.225690  0.327470 -0.689993  0.754202 -0.248573  \
# 1  1.0  0.907542  0.329147  0.359412  1.497970 -0.313010  1.095531 -0.557525
# 2  1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875  1.282322
# 3  0.0  1.344385 -0.876626  0.935913  1.992050  0.882454  1.786066 -1.646778
# 4  1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466 -1.070464
#
#          8         9   ...        19        20        21        22        23
# 0 -1.092064  0.000000  ... -0.010455 -0.045767  3.101961  1.353760  0.979563  \
# 1 -1.588230  2.173076  ... -1.138930 -0.000819  0.000000  0.302220  0.833048
# 2  1.381664  0.000000  ...  1.128848  0.900461  0.000000  0.909753  1.108330
# 3 -0.942383  0.000000  ... -0.678379 -1.360356  0.000000  0.946652  1.028704
# ...

# %%
# %%time

higgs = pd.read_csv('../input/HIGGS.csv.gz', header=None, engine='pyarrow', dtype_backend='numpy_nullable')
higgs.head()
# Out:
# CPU times: user 47.6 s, sys: 7.73 s, total: 55.3 s
# Wall time: 29 s
#     0         1         2         3         4         5         6         7
# 0  1.0  0.869293 -0.635082   0.22569   0.32747 -0.689993  0.754202 -0.248573  \
# 1  1.0  0.907542  0.329147  0.359412   1.49797  -0.31301  1.095531 -0.557525
# 2  1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875  1.282322
# 3  0.0  1.344385 -0.876626  0.935913   1.99205  0.882454  1.786066 -1.646778
# 4  1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466 -1.070464
#
#          8         9   ...        19        20        21        22        23
# 0 -1.092064       0.0  ... -0.010455 -0.045767  3.101961   1.35376  0.979563  \
# 1  -1.58823  2.173076  ...  -1.13893 -0.000819       0.0   0.30222  0.833048
# 2  1.381664       0.0  ...  1.128848  0.900461       0.0  0.909753   1.10833
# 3 -0.942383       0.0  ... -0.678379 -1.360356       0.0  0.946652  1.028704
# ...

# %%
# %%time

higgs = pd.read_csv('../input/HIGGS.csv.gz', header=None)
higgs.head()
# Out:
# CPU times: user 1min 4s, sys: 2.05 s, total: 1min 6s
# Wall time: 1min 6s
#     0         1         2         3         4         5         6         7
# 0  1.0  0.869293 -0.635082  0.225690  0.327470 -0.689993  0.754202 -0.248573  \
# 1  1.0  0.907542  0.329147  0.359412  1.497970 -0.313010  1.095531 -0.557525
# 2  1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875  1.282322
# 3  0.0  1.344385 -0.876626  0.935913  1.992050  0.882454  1.786066 -1.646778
# 4  1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466 -1.070464
#
#          8         9   ...        19        20        21        22        23
# 0 -1.092064  0.000000  ... -0.010455 -0.045767  3.101961  1.353760  0.979563  \
# 1 -1.588230  2.173076  ... -1.138930 -0.000819  0.000000  0.302220  0.833048
# 2  1.381664  0.000000  ...  1.128848  0.900461  0.000000  0.909753  1.108330
# 3 -0.942383  0.000000  ... -0.678379 -1.360356  0.000000  0.946652  1.028704
# ...

# %%
higgs.shape
# Out:
# (11000000, 29)

# %%
# %%time

higgs = pl.read_csv('../input/HIGGS.csv.gz')
higgs.head()
# Out:
# CPU times: user 35.1 s, sys: 8.86 s, total: 43.9 s
# Wall time: 26.7 s
# shape: (5, 29)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 1.00000000 ┆ 8.69293212 ┆ -6.3508182 ┆ 2.25690260 ┆ … ┆ 9.20004844 ┆ 7.21657454 ┆ 9.88750934 ┆ 8.76678347 │
# │ 0000000000 ┆ 8906250000 ┆ 7640533447 ┆ 5295181274 ┆   ┆ 6655273438 ┆ 9674987793 ┆ 6008300781 ┆ 5875854492 │
# │ e+00       ┆ e-01       ┆ 3e-01      ┆ e-01       ┆   ┆ e-01       ┆ e-01       ┆ e-01       ┆ e-01       │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ f64        ┆ f64        ┆ f64        ┆ f64        ┆   ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 1.0        ┆ 0.907542   ┆ 0.329147   ┆ 0.359412   ┆ … ┆ 0.978098   ┆ 0.779732   ┆ 0.992356   ┆ 0.798343   │
# ...
