# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2024-03-02T10:42:23.422608-05:00
#
# Python implementation: CPython
# Python version       : 3.9.6
# IPython version      : 8.10.0
#
# Compiler    : Clang 15.0.0 (clang-1500.0.40.1)
# OS          : Darwin
# Release     : 23.0.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 20
# Architecture: 64bit

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
# %watermark --iversions
# Out:
# numpy : 1.26.4
# pandas: 2.2.0

# %%
# %%time

higgs = pd.read_csv('../input/HIGGS.csv.gz', header=None)
higgs.head()
# Out:
# CPU times: user 56 s, sys: 2.19 s, total: 58.2 s
# Wall time: 58.4 s
#     0         1         2         3         4         5         6         7   \
# 0  1.0  0.869293 -0.635082  0.225690  0.327470 -0.689993  0.754202 -0.248573
# 1  1.0  0.907542  0.329147  0.359412  1.497970 -0.313010  1.095531 -0.557525
# 2  1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875  1.282322
# 3  0.0  1.344385 -0.876626  0.935913  1.992050  0.882454  1.786066 -1.646778
# 4  1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466 -1.070464
#
#          8         9   ...        19        20        21        22        23  \
# 0 -1.092064  0.000000  ... -0.010455 -0.045767  3.101961  1.353760  0.979563
# 1 -1.588230  2.173076  ... -1.138930 -0.000819  0.000000  0.302220  0.833048
# 2  1.381664  0.000000  ...  1.128848  0.900461  0.000000  0.909753  1.108330
# 3 -0.942383  0.000000  ... -0.678379 -1.360356  0.000000  0.946652  1.028704
# 4 -0.921871  0.000000  ... -0.373566  0.113041  0.000000  0.755856  1.361057
#
#          24        25        26        27        28
# 0  0.978076  0.920005  0.721657  0.988751  0.876678
# 1  0.985700  0.978098  0.779732  0.992356  0.798343
# 2  0.985692  0.951331  0.803252  0.865924  0.780118
# 3  0.998656  0.728281  0.869200  1.026736  0.957904
# 4  0.986610  0.838085  1.133295  0.872245  0.808487
#
# [5 rows x 29 columns]

# %%
y = higgs[0].values
X = higgs[higgs.columns[1:]].values

# %%
X.shape
# Out:
# (11000000, 28)

# %%
pca = PCA()

# %%
# %%time
pca.fit(X)
# Out:
# CPU times: user 15.2 s, sys: 50.6 s, total: 1min 5s
# Wall time: 5.83 s
# PCA()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.11581302 0.09659324 0.08451179 0.07000956 0.0641502  0.05651781
#  0.055588   0.05446682 0.05291956 0.04468113 0.04248516 0.04108151
#  0.03885671 0.03775394 0.0255504  0.02181292 0.01979832 0.0185323
#  0.0164828  0.01047363 0.00779365 0.00702242 0.00586635 0.00531234
#  0.00300572 0.00135565 0.00109707 0.00046801]

# %%
print(pca.singular_values_)
# Out:
# [5003.04579674 4569.08410101 4273.80238613 3889.86442375 3723.52934224
#  3495.01026812 3466.14157391 3431.00866926 3381.92447804 3107.54801903
#  3030.22187645 2979.74405902 2897.93616035 2856.51778931 2349.9286858
#  2171.2644086  2068.56851579 2001.33813602 1887.43176313 1504.54204777
#  1297.85481132 1231.96725983 1126.00313785 1071.51606182  805.99048182
#   541.28995831  486.93646199  318.03950345]

# %%
# %%time
pca.transform(X)
# Out:
# CPU times: user 13.1 s, sys: 26 s, total: 39.1 s
# Wall time: 3.33 s
# array([[ 2.37588413e+00, -1.40848072e+00, -9.87583802e-02, ...,
#         -9.30674710e-02,  2.61639870e-02, -4.98485168e-02],
#        [-1.00133451e+00, -1.17815301e+00, -1.97463279e+00, ...,
#          1.36183530e-02, -8.75392642e-02, -9.11670786e-02],
#        [-1.46140860e+00,  2.60207883e+00,  1.03877046e+00, ...,
#          1.01052557e-01, -6.21568097e-02, -9.54552415e-04],
#        ...,
#        [-1.11283970e+00,  2.08201391e+00, -2.03461526e+00, ...,
#         -1.04776130e-03, -2.30256243e-02, -7.89225904e-03],
#        [-5.83522464e-01,  9.56872917e-02, -1.02160119e+00, ...,
#          1.21177216e-01,  1.33758789e-02, -6.71757103e-02],
#        [-9.20517152e-01, -2.25655857e+00, -1.89600142e+00, ...,
#         -3.17351472e-02, -1.53369946e-02,  7.41684997e-03]])
