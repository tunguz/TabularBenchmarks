# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2024-11-18T13:32:25.786000-05:00
#
# Python implementation: CPython
# Python version       : 3.10.8
# IPython version      : 8.6.0
#
# Compiler    : Clang 14.0.0 (clang-1400.0.29.102)
# OS          : Darwin
# Release     : 23.6.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 8
# Architecture: 64bit

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from time import time, sleep
import sklearn
import gc
import os

# %%
# %watermark --iversions
# Out:
# pandas : 2.2.3
# numpy  : 2.1.3
# sklearn: 1.5.2

# %%
time()
# Out:
# 1731954748.5534122

# %%
X_num_train = np.load('../../input/higgs_small_roc/X_num_train.npy')
X_num_val = np.load('../../input/higgs_small_roc/X_num_val.npy')
X_num_test = np.load('../../input/higgs_small_roc/X_num_test.npy')

y_train = np.load('../../input/higgs_small_roc/y_train.npy')
y_val = np.load('../../input/higgs_small_roc/y_val.npy')
y_test = np.load('../../input/higgs_small_roc/y_test.npy')

# %%
# %%time
times = []
for i in range(10):
    time_now = time()
    model = SVC()
    model.fit(X_num_train, y_train)
    time_now = time() - time_now
    print(time_now)
    times.append(time_now)
# Out:
# 67.95382404327393
# 68.1878309249878
# 67.61956095695496
# 67.7453019618988
# 68.09441995620728
# 67.56620693206787
# 67.95924401283264
# 67.61595916748047
# 68.09793710708618
# 68.59243488311768
# CPU times: user 11min 16s, sys: 2.54 s, total: 11min 19s
# Wall time: 11min 19s

# %%
np.mean(times)
# Out:
# np.float64(67.94327199459076)

# %%
np.median(times)
# Out:
# np.float64(67.95653402805328)
